# %% [markdown]
# # Reading data from massive ECCC file

# %%
import pandas as pd
import os
from math import ceil

def split_excel_file(
    file_path: str,
    output_dir: str,
    rows_per_file: int = 100000,
    sheet_name: str = 0
) -> list:
    """
    Splits a large Excel file into multiple smaller files.
    
    Parameters:
    -----------
    file_path : str
        Path to the input Excel file
    output_dir : str
        Directory where split files will be saved
    rows_per_file : int
        Number of rows per output file
    sheet_name : str or int
        Sheet to read from the Excel file
        
    Returns:
    --------
    list
        List of paths to the created files
    """
    
    # Create output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)
    
    # Get total number of rows
    print("Counting rows...")
    nrows = pd.read_excel(file_path, sheet_name=sheet_name).shape[0]
    
    # Calculate number of files needed
    num_files = ceil(nrows / rows_per_file)
    output_files = []
    
    print(f"Splitting {nrows} rows into {num_files} files...")
    
    for i in range(num_files):
        # Calculate row range for this chunk
        start_row = i * rows_per_file
        
        # Read chunk of rows
        print(f"Reading rows {start_row} to {start_row + rows_per_file}...")
        df_chunk = pd.read_excel(
            file_path,
            sheet_name=sheet_name,
            skiprows=start_row,
            nrows=rows_per_file
        )
        
        # Generate output filename
        base_name = os.path.splitext(os.path.basename(file_path))[0]
        output_file = os.path.join(output_dir, f"{base_name}_part_{i+1}.xlsx")
        
        # Save chunk to new file
        print(f"Saving {output_file}...")
        df_chunk.to_excel(output_file, index=False)
        output_files.append(output_file)
        
        # Clear memory
        del df_chunk
        
    print(f"Successfully split file into {len(output_files)} parts")
    return output_files

# %% [markdown]
# ## Change in load
# According to the report from ECCC
# ![image.png](attachment:2ffce032-6eab-40e1-8b38-afb5ed189deb.png)

# %% [markdown]
# ## Reading the data

# %%
import pandas as pd
import glob
base_folder = '../data/raw_data/heatpump/ECCC_data_parts/'
filenames = glob.glob(f'{base_folder}*part*') 
filenames.sort()
print("Reading filename :", filenames[3])
data_part= pd.read_excel(filenames[3])
# Out:
# Reading filename : ../data/raw_data/heatpump/ECCC_data_parts\ECCC_2023_part_13.xlsx

# %% [markdown]
# ## Data column descriptions

# %% [markdown]
# ![image.png](attachment:eac58136-9cc5-4d63-a5c4-1b7efeb6f45f.png)

# %% [markdown]
# ![image.png](attachment:2c776ea2-f3ad-4899-9557-c5ff3081c65b.png)

# %% [markdown]
# ![image.png](attachment:c19222d0-337c-4e75-bee2-c64db4580718.png)

# %% [markdown]
# ![image.png](attachment:93217d34-a0cb-48fe-8958-8d0c25884d36.png)

# %% [markdown]
# ![image.png](attachment:499b02c2-4927-4104-aefa-0ba95b4544ee.png)

# %% [markdown]
# ![image.png](attachment:d3ff699f-0a23-441d-8012-56aba2d48687.png)

# %% [markdown]
# ![image.png](attachment:dbe62540-9e48-499b-999b-f6e45c1b0a92.png)

# %% [markdown]
# https://data.open-power-system-data.org/when2heat/2023-07-27/README.md

# %% [markdown]
# ## Understanding the data

# %%
heatpumpdata = ['HPCAP', 'HPEquipType', 'HPESTAR' ,'HPSOURCE', 'COP']
building_chars = ['HEATEDFLOORAREA', 'BUILDINGTYPE', 'HOUSEID', 'HOUSEREGION', 'YEARBUILT']
location_data = ['HOUSEREGION', 'CLIENTPCODE', 'CLIENTCITY']

thermal_envelope_metrics = ['EGHHLWALLS', 'EGHHLCEILING', 'EGHHLWINDOOR', 'EGHHLFOUND', 'EGHHLEXPOSEDFLR',  'EGHHLAIR']
energy_performance = ['EGHRATING', 'EGHSPACEENERGY', 'ERSENERGYINTENSITY']
energy_consumption_metrics = ['EGHFCONTOTAL' ,'EGHFCONELEC','EGHFCONNGAS','EGHFCONOIL' , 'EGHFCONPROP','EGHFCONWOOD','EGHFCONWOODGJ']
heating_specific_eng_consumption_metrics = ['EGHHEATFCONSE', 
                                            'EGHHEATFCONSG', 
                                            'EGHHEATFCONSO', 
                                            'EGHHEATFCONSP' ,
                                            'EGHHEATFCONSW',
                                            'ERSWATERHEATINGENERGY',
                                            'EGHSPACEENERGY',
                                            'ERSSPACECOOLENERGY']
weather_data = ['WEATHERLOC', 'WTHDATA', 'CoolingSeasonMonths', 'TMAIN', 'QTOT', 'QWARN']
temperature_setting = ['ThermostatCooling', 'ThermostatHeatingNighttime']
time_info = ['CREATIONDATE', 'ENTRYDATE']

#efficiency of the heating equipment

# %%
import numpy as np 
import matplotlib.pyplot as plt 
for c in thermal_envelope_metrics:
    print(c, data_no_dup[c].mean())
thermal_data = np.array(data_no_dup[thermal_envelope_metrics])
plt.hist(thermal_data[:,-1]/thermal_data.sum(axis=1), bins=100)
(thermal_data[:,-1]/thermal_data.sum(axis=1)).mean()
# Out:
#  EGHHLWALLS 24668.05716
#  EGHHLCEILING 8397.075239999998
#  EGHHLWINDOOR 28437.26713
#  EGHHLFOUND 29118.587940000005
#  EGHHLEXPOSEDFLR 784.77636
#  EGHHLAIR 23147.646010000004
# 0.19634777181256508

# %%
sum(data_no_dup[' HPESTAR']=='C448')
# Out:
# 42

# %%
data[230]
# Out:
# array([  326. , 81254. ,     0. ,     0. ,     0. , 26123.6, 81580.1,
#         3629.7])

# %% [markdown]
# uniq_id

# %%
data_part[data_part[' HOUSEID']==1108107.0 ].to_json('./house_1108107.json')

# %%
data_no_dup = data_part.drop_duplicates()

# %%
data_no_dup.columns
# Out:
# Index(['ACCENTESTAR', ' ACMODELNUMBER', ' ACWINDESTAR', ' ACWINDNUM', ' AHRI',
#        ' AIR50P', ' AIRCONDTYPE', ' AIRCOP', ' ASHPHSPF', ' ASHPHSPF2',
#        ...
#        ' RefHLWinDoor', ' RefHLExposedFlr', ' RefHLWindow', ' RefHLDoor',
#        ' RefDesHtLoss', ' RefDesCoolLoss', ' RefSpaceEnergy',
#        ' RefSpaceCoolEnergy', ' RefWaterHeatEnergy', ' RefVentilationEnergy'],
#       dtype='object', length=435)

# %%
data_no_dup[weather_data]
# Out:
#                         WEATHERLOC  WTHDATA   CoolingSeasonMonths   TMAIN  \
# 0              L'ASSOMPTION,QUEBEC  Wth2020                   0.0      21
# 1                   NICOLET,QUEBEC  Wth2020                   6.0      21
# 2                   NICOLET,QUEBEC  Wth2020                   0.0      21
# 3     BARRAGE TEMISCAMINGUE,QUEBEC  Wth2020                   0.0      21
# 4              OTTAWA INTL,ONTARIO  Wth2020                   0.0      21
# ...                            ...      ...                   ...     ...
# 9995       VERNON,BRITISH COLUMBIA  Wth2020                   NaN      21
# 9996       VERNON,BRITISH COLUMBIA  Wth2020                   NaN      21
# 9997       VERNON,BRITISH COLUMBIA  Wth2020                   NaN      21
# 9998       VERNON,BRITISH COLUMBIA  Wth2020                   NaN      21
# 9999       VERNON,BRITISH COLUMBIA  Wth2020                   NaN      21
#
#        QTOT   QWARN
# 0     22.63   32.00
# 1     53.09   19.99
# 2     51.68   19.99
# 3     69.13   19.58
# 4     32.05   32.00
# ...     ...     ...
# 9995  40.84   24.97
# 9996  40.84   24.97
# 9997  40.84   24.97
# 9998  40.84   24.97
# 9999  44.56   26.52
#
# [9996 rows x 6 columns]

# %% [markdown]
# # Heat pump home heating cycle

# %%
opcycle_data = pd.read_csv('../data/raw_data/heatpump/when2heat.csv', sep=';')

# %%
opcycle_data_at = opcycle_data[list(opcycle_data.columns[0:2]) + list(opcycle_data.columns[3+(23*5):3+(23*6)])]

# %%
opcycle_data_at.columns
# Out:
# Index(['utc_timestamp', 'cet_cest_timestamp', 'DE_COP_GSHP_water',
#        'DE_COP_WSHP_floor', 'DE_COP_WSHP_radiator', 'DE_COP_WSHP_water',
#        'DE_heat_demand_space', 'DE_heat_demand_space_COM',
#        'DE_heat_demand_space_MFH', 'DE_heat_demand_space_SFH',
#        'DE_heat_demand_total', 'DE_heat_demand_water',
#        'DE_heat_demand_water_COM', 'DE_heat_demand_water_MFH',
#        'DE_heat_demand_water_SFH', 'DE_heat_profile_space_COM',
#        'DE_heat_profile_space_MFH', 'DE_heat_profile_space_SFH',
#        'DE_heat_profile_water_COM', 'DE_heat_profile_water_MFH',
#        'DE_heat_profile_water_SFH', 'DK_COP_ASHP_floor',
#        'DK_COP_ASHP_radiator', 'DK_COP_ASHP_water', 'DK_COP_GSHP_floor'],
#       dtype='object')

# %%
sns.lineplot(opcycle_data_at[['DE_heat_demand_space', 'DE_heat_demand_water','DE_heat_demand_total']].iloc[24*110:24*111])
# Out:
# <Axes: >

# %% [markdown]
# # Heat pump penetration rate

# %%
wrf = pd.read_csv("../data/raw_data/weather/climate_hourly_AB_3011240_2021_P1H.csv", encoding_errors='ignore')

# %% [markdown]
# # Getting weather data

# %%
import requests
import openmeteo_requests

import requests_cache
import pandas as pd
from retry_requests import retry

def get_lat_lon(city_or_postal, api_key='c65af5e86ba0434b958b89eca2995f83'):
    """
    Get latitude and longitude for a given city name or postal code using OpenCage API.
    """
    geocode_url = "https://api.opencagedata.com/geocode/v1/json"
    params = {
        "q": city_or_postal,
        "key": api_key,
    }
    response = requests.get(geocode_url, params=params)
    if response.status_code == 200:
        data = response.json()
        if data['results']:
            location = data['results'][0]['geometry']
            return location['lat'], location['lng']
        else:
            raise ValueError("Location not found!")
    else:
        response.raise_for_status()

def get_historical_weather(lat, lon, start_date, end_date):
    """
    Fetch historical hourly weather data from Open-Meteo API.
    """
    weather_url = "https://archive-api.open-meteo.com/v1/archive"
    params = {
        "latitude": lat,
        "longitude": lon,
        "start_date": start_date,
        "end_date": end_date,
        "hourly": "temperature_2m",
        "timezone": "auto",
    }
    response = requests.get(weather_url, params=params)
    if response.status_code == 200:
        return response.json()
    else:
        response.raise_for_status()


def get_historical_weather_data_formatted(lat, long, start_date, end_date, openmeteo):
    url = "https://archive-api.open-meteo.com/v1/archive"
    params = {
    	"latitude": lat,
    	"longitude": long,
    	"hourly": ["temperature_2m", 'wind_speed_10m'],
    	"timezone": "auto",
    	"start_date": start_date,
    	"end_date": end_date
    }
    responses = openmeteo.weather_api(url, params=params)
    
    # Process first location. Add a for-loop for multiple locations or weather models
    response = responses[0]
    print(f"Coordinates {response.Latitude()}°N {response.Longitude()}°E")
    print(f"Elevation {response.Elevation()} m asl")
    print(f"Timezone {response.Timezone()} {response.TimezoneAbbreviation()}")
    print(f"Timezone difference to GMT+0 {response.UtcOffsetSeconds()} s")
    
    # Process hourly data. The order of variables needs to be the same as requested.
    hourly = response.Hourly()
    hourly_temperature_2m = hourly.Variables(0).ValuesAsNumpy()
    hourly_wind_speed_10m = hourly.Variables(1).ValuesAsNumpy()
    
    hourly_data = {"date": pd.date_range(
    	start = pd.to_datetime(hourly.Time(), unit = "s", utc = True),
    	end = pd.to_datetime(hourly.TimeEnd(), unit = "s", utc = True),
    	freq = pd.Timedelta(seconds = hourly.Interval()),
    	inclusive = "left"
    )}
    hourly_data["temperature_2m"] = hourly_temperature_2m
    hourly_data["wind_speed_10m"] = hourly_wind_speed_10m
    
    hourly_dataframe = pd.DataFrame(data = hourly_data)
    return hourly_dataframe

# %%
# find the number of unique locations in the heatpump data
import glob 
import pandas as pd 
import tqdm
base_folder = '../data/raw_data/heatpump/ECCC_data_parts/'
filenames = glob.glob(f'{base_folder}/*')
# cities_with_FSA = []
# total_pcodes = []
for f in tqdm.tqdm(filenames[3:]):
    data = pd.read_excel(f)
    locations = set(data[' CLIENTCITY'].str.strip().str.lower()+ ','+ data[' HOUSEREGION'].str.strip().str.lower() + ',' +data[' CLIENTPCODE'].str.strip().str.lower())
    pcodes = set(data[' CLIENTPCODE'].str.strip().str.lower())
    print("Num of cities: ", len(locations))
    print("Num of pcodes: ", len(pcodes))
    cities_with_FSA.extend(locations)
    total_pcodes.extend(pcodes)
    cities_with_FSA = list(set(cities_with_FSA))
    total_pcodes = list(set(total_pcodes))
    print("New total cities: ", len(cities_with_FSA))
    print("New total pcodes: ", len(total_pcodes))
# Out:
#   2%|▉                                         | 1/47 [00:22<17:25, 22.73s/it]
# Num of cities:  2135
# Num of pcodes:  1021
# New total cities:  4211
# New total pcodes:  1163
#   4%|█▊                                        | 2/47 [00:45<17:16, 23.04s/it]
# Num of cities:  2138
# Num of pcodes:  1022
# New total cities:  4746
# New total pcodes:  1180
#   6%|██▋                                       | 3/47 [01:10<17:23, 23.71s/it]
# Num of cities:  2081
# Num of pcodes:  1017
# New total cities:  5157
# New total pcodes:  1194
#   9%|███▌                                      | 4/47 [01:36<17:30, 24.44s/it]
# Num of cities:  2082
# Num of pcodes:  1009
# New total cities:  5542
# New total pcodes:  1203
#  11%|████▍                                     | 5/47 [02:02<17:34, 25.12s/it]
# Num of cities:  2099
# Num of pcodes:  1032
# New total cities:  5916
# New total pcodes:  1243
#  13%|█████▎                                    | 6/47 [02:24<16:34, 24.26s/it]
# Num of cities:  2030
# Num of pcodes:  1061
# New total cities:  6262
# New total pcodes:  1296
#  15%|██████▎                                   | 7/47 [02:49<16:09, 24.24s/it]
# Num of cities:  2108
# Num of pcodes:  1102
# New total cities:  6627
# New total pcodes:  1343
#  17%|███████▏                                  | 8/47 [03:12<15:29, 23.84s/it]
# Num of cities:  2809
# Num of pcodes:  1159
# New total cities:  7944
# New total pcodes:  1609
#  19%|████████                                  | 9/47 [03:36<15:17, 24.13s/it]
# Num of cities:  2118
# Num of pcodes:  1140
# New total cities:  8181
# New total pcodes:  1618
#  21%|████████▋                                | 10/47 [04:01<14:56, 24.24s/it]
# Num of cities:  2247
# Num of pcodes:  1217
# New total cities:  8455
# New total pcodes:  1621
#  23%|█████████▌                               | 11/47 [04:26<14:44, 24.57s/it]
# Num of cities:  2268
# Num of pcodes:  1223
# New total cities:  8731
# New total pcodes:  1624
#  26%|██████████▍                              | 12/47 [04:50<14:08, 24.25s/it]
# Num of cities:  2306
# Num of pcodes:  1268
# New total cities:  8992
# New total pcodes:  1628
#  28%|███████████▎                             | 13/47 [05:15<13:58, 24.66s/it]
# Num of cities:  2256
# Num of pcodes:  1246
# New total cities:  9233
# New total pcodes:  1633
#  30%|████████████▏                            | 14/47 [05:38<13:10, 23.97s/it]
# Num of cities:  2183
# Num of pcodes:  1223
# New total cities:  9448
# New total pcodes:  1636
#  32%|█████████████                            | 15/47 [06:07<13:38, 25.59s/it]
# Num of cities:  2187
# Num of pcodes:  1242
# New total cities:  9662
# New total pcodes:  1642
#  34%|█████████████▉                           | 16/47 [06:31<12:59, 25.14s/it]
# Num of cities:  2314
# Num of pcodes:  1273
# New total cities:  9888
# New total pcodes:  1648
#  36%|██████████████▊                          | 17/47 [07:01<13:17, 26.59s/it]
# Num of cities:  2206
# Num of pcodes:  1235
# New total cities:  10102
# New total pcodes:  1654
#  38%|███████████████▋                         | 18/47 [07:27<12:43, 26.33s/it]
# Num of cities:  2229
# Num of pcodes:  1230
# New total cities:  10313
# New total pcodes:  1658
#  40%|████████████████▌                        | 19/47 [07:53<12:19, 26.41s/it]
# Num of cities:  2008
# Num of pcodes:  474
# New total cities:  10711
# New total pcodes:  1659
#  43%|█████████████████▍                       | 20/47 [08:19<11:49, 26.28s/it]
# Num of cities:  2197
# Num of pcodes:  1256
# New total cities:  10892
# New total pcodes:  1661
#  45%|██████████████████▎                      | 21/47 [08:46<11:24, 26.31s/it]
# Num of cities:  2236
# Num of pcodes:  1258
# New total cities:  11083
# New total pcodes:  1667
#  47%|███████████████████▏                     | 22/47 [09:13<11:06, 26.65s/it]
# Num of cities:  2217
# Num of pcodes:  1239
# New total cities:  11250
# New total pcodes:  1669
#  49%|████████████████████                     | 23/47 [09:38<10:25, 26.07s/it]
# Num of cities:  2275
# Num of pcodes:  1274
# New total cities:  11398
# New total pcodes:  1674
#  51%|████████████████████▉                    | 24/47 [10:04<09:59, 26.07s/it]
# Num of cities:  2336
# Num of pcodes:  1218
# New total cities:  11578
# New total pcodes:  1677
#  53%|█████████████████████▊                   | 25/47 [10:29<09:29, 25.87s/it]
# Num of cities:  2322
# Num of pcodes:  1248
# New total cities:  11763
# New total pcodes:  1680
#  55%|██████████████████████▋                  | 26/47 [10:57<09:14, 26.38s/it]
# Num of cities:  2296
# Num of pcodes:  1240
# New total cities:  11925
# New total pcodes:  1682
#  57%|███████████████████████▌                 | 27/47 [11:24<08:52, 26.61s/it]
# Num of cities:  2242
# Num of pcodes:  1250
# New total cities:  12066
# New total pcodes:  1684
#  60%|████████████████████████▍                | 28/47 [11:53<08:40, 27.37s/it]
# Num of cities:  2365
# Num of pcodes:  1255
# New total cities:  12227
# New total pcodes:  1686
#  62%|█████████████████████████▎               | 29/47 [12:20<08:08, 27.14s/it]
# Num of cities:  2301
# Num of pcodes:  1256
# New total cities:  12382
# New total pcodes:  1691
#  64%|██████████████████████████▏              | 30/47 [12:46<07:34, 26.71s/it]
# Num of cities:  1767
# Num of pcodes:  582
# New total cities:  12586
# New total pcodes:  1693
#  66%|███████████████████████████              | 31/47 [13:15<07:18, 27.43s/it]
# Num of cities:  2365
# Num of pcodes:  1226
# New total cities:  12733
# New total pcodes:  1694
#  68%|███████████████████████████▉             | 32/47 [13:43<06:54, 27.64s/it]
# Num of cities:  2341
# Num of pcodes:  1283
# New total cities:  12885
# New total pcodes:  1697
#  70%|████████████████████████████▊            | 33/47 [14:11<06:30, 27.86s/it]
# Num of cities:  2362
# Num of pcodes:  1237
# New total cities:  13025
# New total pcodes:  1698
#  72%|█████████████████████████████▋           | 34/47 [14:38<05:56, 27.42s/it]
# Num of cities:  2446
# Num of pcodes:  1262
# New total cities:  13185
# New total pcodes:  1701
#  74%|██████████████████████████████▌          | 35/47 [15:10<05:45, 28.80s/it]
# Num of cities:  2500
# Num of pcodes:  1309
# New total cities:  13350
# New total pcodes:  1704
#  77%|███████████████████████████████▍         | 36/47 [15:39<05:17, 28.85s/it]
# Num of cities:  2606
# Num of pcodes:  1322
# New total cities:  13511
# New total pcodes:  1706
#  79%|████████████████████████████████▎        | 37/47 [16:06<04:43, 28.32s/it]
# Num of cities:  2623
# Num of pcodes:  1321
# New total cities:  13683
# New total pcodes:  1706
#  81%|█████████████████████████████████▏       | 38/47 [16:33<04:12, 28.02s/it]
# Num of cities:  2342
# Num of pcodes:  1245
# New total cities:  13851
# New total pcodes:  1710
#  83%|██████████████████████████████████       | 39/47 [17:00<03:41, 27.64s/it]
# Num of cities:  2213
# Num of pcodes:  1219
# New total cities:  13999
# New total pcodes:  1713
#  85%|██████████████████████████████████▉      | 40/47 [17:28<03:15, 27.93s/it]
# Num of cities:  2020
# Num of pcodes:  1114
# New total cities:  14130
# New total pcodes:  1719
#  87%|███████████████████████████████████▊     | 41/47 [17:53<02:42, 27.09s/it]
# Num of cities:  1535
# Num of pcodes:  592
# New total cities:  14249
# New total pcodes:  1723
#  89%|████████████████████████████████████▋    | 42/47 [18:19<02:13, 26.73s/it]
# Num of cities:  1829
# Num of pcodes:  978
# New total cities:  14430
# New total pcodes:  1727
#  91%|█████████████████████████████████████▌   | 43/47 [18:38<01:36, 24.21s/it]
# Num of cities:  2042
# Num of pcodes:  1155
# New total cities:  14562
# New total pcodes:  1734
#  94%|██████████████████████████████████████▍  | 44/47 [19:01<01:12, 24.07s/it]
# Num of cities:  1472
# Num of pcodes:  566
# New total cities:  14678
# New total pcodes:  1734
#  96%|███████████████████████████████████████▎ | 45/47 [19:27<00:48, 24.44s/it]
# Num of cities:  1494
# Num of pcodes:  574
# New total cities:  14778
# New total pcodes:  1734
#  98%|████████████████████████████████████████▏| 46/47 [19:52<00:24, 24.77s/it]
# Num of cities:  1448
# Num of pcodes:  585
# New total cities:  14859
# New total pcodes:  1735
# 100%|█████████████████████████████████████████| 47/47 [20:16<00:00, 25.88s/it]
# Num of cities:  1248
# Num of pcodes:  679
# New total cities:  14956
# New total pcodes:  1736

# %%
import time
#get weather data for the respective cities
save_folder = '../data/raw_data/weather/by_FSA'
# Setup the Open-Meteo API client with cache and retry on error
cache_session = requests_cache.CachedSession('.cache', expire_after = 3600)
retry_session = retry(cache_session, retries = 5, backoff_factor = 0.2)
openmeteo = openmeteo_requests.Client(session = retry_session)
# Make sure all required weather variables are listed here
# The order of variables in hourly or daily is important to assign them correctly below

start_date = '2023-01-01'
end_date = '2024-01-01'

# weather_info_dict = {}
# city_latlong = {}

#fsa_latlong =  {}
#fsa_weather_info_dict = {}
for fsa in total_pcodes:
    print(fsa)
    if fsa not in fsa_latlong.keys():
        print("Performing coord search")
        try:
            lat, long = get_lat_lon(fsa)
            fsa_latlong[fsa] = [lat, long]
        except:
            #city_latlong[fd] = [None, None]
            print(f"Location data not found for {fsa}. Skipping. . . ")
    
    try:    
        lat, long = fsa_latlong[fsa]
        
        weather_data = get_historical_weather_data_formatted(lat, long, start_date, end_date, openmeteo)
        weather_data['FSA'] = fsa
        fsa_weather_info_dict[fsa] = weather_data
        weather_data.to_csv(f'{save_folder}/{fsa}_{start_date}_{end_date}.csv')
    except Exception as e:
        print("problem getting weather information")
        print(e)
        
    time.sleep(3)

#last location: saint-simon, québec
# Out:
# Performing coord search
# Location data not found for . Skipping. . .
# problem getting weather information
# ''
# e7n
# Coordinates 46.080841064453125°N -67.5357666015625°E
# Elevation 160.0 m asl
# Timezone b'America/Moncton' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# s6x
# Coordinates 53.1810188293457°N -105.68182373046875°E
# Elevation 454.0 m asl
# Timezone b'America/Regina' b'GMT-6'
# Timezone difference to GMT+0 -21600 s
# g0t
# Coordinates 49.033390045166016°N -69.608154296875°E
# Elevation 527.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# h7c
# Coordinates 45.588748931884766°N -73.58493041992188°E
# Elevation 29.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# e4c
# Coordinates 45.86994552612305°N -65.93353271484375°E
# Elevation 0.0 m asl
# Timezone b'America/Moncton' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# t2a
# Coordinates 51.07205581665039°N -114.03227233886719°E
# Elevation 1064.0 m asl
# Timezone b'America/Edmonton' b'GMT-7'
# Timezone difference to GMT+0 -25200 s
# p2w
# Coordinates 5.3778557777404785°N 132.91390991210938°E
# Elevation 0.0 m asl
# Timezone b'Pacific/Palau' b'GMT+9'
# Timezone difference to GMT+0 32400 s
# m5v
# Coordinates 43.620384216308594°N -79.56326293945312°E
# Elevation 79.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# m4g
# Coordinates 43.6906852722168°N -79.4117431640625°E
# Elevation 136.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# t9v
# Coordinates 53.25131607055664°N -110.15179443359375°E
# Elevation 667.0 m asl
# Timezone b'America/Edmonton' b'GMT-7'
# Timezone difference to GMT+0 -25200 s
# h1t
# Coordinates 45.588748931884766°N -73.58493041992188°E
# Elevation 48.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# s4w
# Coordinates 50.43936538696289°N -104.60316467285156°E
# Elevation 571.0 m asl
# Timezone b'America/Regina' b'GMT-6'
# Timezone difference to GMT+0 -21600 s
# b4e
# Coordinates 44.81546401977539°N -63.70941162109375°E
# Elevation 101.0 m asl
# Timezone b'America/Halifax' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# problem getting weather information
# [Errno 13] Permission denied: '../data/raw_data/weather/by_FSA/b4e_2023-01-01_2024-01-01.csv'
# j0y
# Coordinates 52.12653732299805°N -75.24862670898438°E
# Elevation 357.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# g2b
# Performing coord search
# Coordinates 46.854129791259766°N -71.35922241210938°E
# Elevation 84.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# p0h
# Performing coord search
# Coordinates 46.2917366027832°N -79.36102294921875°E
# Elevation 201.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# j0d
# Performing coord search
# Coordinates 28.646747589111328°N 77.0695571899414°E
# Elevation 218.0 m asl
# Timezone b'Asia/Kolkata' b'GMT+5:30'
# Timezone difference to GMT+0 19800 s
# k7k
# Performing coord search
# Coordinates 4.463972091674805°N 114.02948760986328°E
# Elevation 6.0 m asl
# Timezone b'Asia/Kuching' b'GMT+8'
# Timezone difference to GMT+0 28800 s
# p0o
# Performing coord search
# Coordinates 43.901580810546875°N 11.045454978942871°E
# Elevation 240.0 m asl
# Timezone b'Europe/Rome' b'GMT+1'
# Timezone difference to GMT+0 3600 s
# l3b
# Performing coord search
# Coordinates 42.98769760131836°N -79.16790771484375°E
# Elevation 184.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# l0j
# Performing coord search
# Coordinates 43.83127975463867°N -79.65203857421875°E
# Elevation 216.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# h1a
# Performing coord search
# Coordinates 45.65904998779297°N -73.55905151367188°E
# Elevation 15.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# y0a
# Performing coord search
# Coordinates 61.54656982421875°N -130.92909240722656°E
# Elevation 1178.0 m asl
# Timezone b'America/Whitehorse' b'GMT-7'
# Timezone difference to GMT+0 -25200 s
# a2n
# Performing coord search
# Coordinates 48.541297912597656°N -58.484832763671875°E
# Elevation 15.0 m asl
# Timezone b'America/St_Johns' b'GMT-3:30'
# Timezone difference to GMT+0 -12600 s
# r1a
# Performing coord search
# Coordinates 50.15816879272461°N -96.93521118164062°E
# Elevation 226.0 m asl
# Timezone b'America/Winnipeg' b'GMT-6'
# Timezone difference to GMT+0 -21600 s
# t8b
# Performing coord search
# Coordinates 53.46221160888672°N -113.3587646484375°E
# Elevation 720.0 m asl
# Timezone b'America/Edmonton' b'GMT-7'
# Timezone difference to GMT+0 -25200 s
# l6m
# Performing coord search
# Coordinates 43.47978591918945°N -79.729736328125°E
# Elevation 157.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# l3p
# Performing coord search
# Coordinates 43.901580810546875°N -79.22726440429688°E
# Elevation 213.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# m6l
# Performing coord search
# Coordinates 43.6906852722168°N -79.5474853515625°E
# Elevation 156.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# m3l
# Performing coord search
# Coordinates 43.760982513427734°N -79.53170776367188°E
# Elevation 153.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# g1b
# Performing coord search
# Coordinates 46.9244270324707°N -71.32901000976562°E
# Elevation 306.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# l2n
# Performing coord search
# Coordinates 43.19859313964844°N -79.25372314453125°E
# Elevation 93.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# p3b
# Performing coord search
# Coordinates 60.281192779541016°N 24.871192932128906°E
# Elevation 53.0 m asl
# Timezone b'Europe/Helsinki' b'GMT+2'
# Timezone difference to GMT+0 7200 s
# n2h
# Performing coord search
# Coordinates -0.24604569375514984°N -78.40750122070312°E
# Elevation 2571.0 m asl
# Timezone b'America/Guayaquil' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# n0p
# Performing coord search
# Coordinates 42.4253044128418°N -82.20263671875°E
# Elevation 180.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# r3w
# Performing coord search
# Coordinates 49.94727325439453°N -97.05575561523438°E
# Elevation 231.0 m asl
# Timezone b'America/Winnipeg' b'GMT-6'
# Timezone difference to GMT+0 -21600 s
# j5a
# Performing coord search
# Coordinates 45.37785339355469°N -73.5211181640625°E
# Elevation 29.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# g9c
# Performing coord search
# Coordinates 46.362037658691406°N -72.72000122070312°E
# Elevation 50.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# b2z
# Performing coord search
# Coordinates 44.74516677856445°N -63.472198486328125°E
# Elevation 49.0 m asl
# Timezone b'America/Halifax' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# r9a
# Performing coord search
# Coordinates 53.6731071472168°N -101.2283935546875°E
# Elevation 259.0 m asl
# Timezone b'America/Winnipeg' b'GMT-6'
# Timezone difference to GMT+0 -21600 s
# l8h
# Performing coord search
# Coordinates 43.268890380859375°N -79.91030883789062°E
# Elevation 78.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# l4b
# Performing coord search
# Coordinates 43.83127975463867°N -79.37973022460938°E
# Elevation 212.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# g1k
# Performing coord search
# Coordinates 46.78382873535156°N -71.24392700195312°E
# Elevation 15.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# k7c
# Performing coord search
# Coordinates 45.16695785522461°N -76.12149047851562°E
# Elevation 133.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# v1h
# Performing coord search
# Coordinates 50.29876708984375°N -119.26185607910156°E
# Elevation 948.0 m asl
# Timezone b'America/Vancouver' b'GMT-8'
# Timezone difference to GMT+0 -28800 s
# h1b
# Performing coord search
# Coordinates 45.65904998779297°N -73.55905151367188°E
# Elevation 17.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# e4b
# Performing coord search
# Coordinates 46.080841064453125°N -66.10491943359375°E
# Elevation 37.0 m asl
# Timezone b'America/Moncton' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# n9g
# Performing coord search
# Coordinates -0.24604569375514984°N -78.40750122070312°E
# Elevation 2542.0 m asl
# Timezone b'America/Guayaquil' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# j7h
# Performing coord search
# Coordinates 45.588748931884766°N -73.86795043945312°E
# Elevation 49.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# m6h
# Performing coord search
# Coordinates 43.6906852722168°N -79.4117431640625°E
# Elevation 120.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# j2b
# Performing coord search
# Coordinates 45.86994552612305°N -72.48419189453125°E
# Elevation 94.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# v9n
# Performing coord search
# Coordinates 49.666080474853516°N -125.03460693359375°E
# Elevation 40.0 m asl
# Timezone b'America/Vancouver' b'GMT-8'
# Timezone difference to GMT+0 -28800 s
# a5a
# Performing coord search
# Coordinates 48.18980407714844°N -53.93988037109375°E
# Elevation 56.0 m asl
# Timezone b'America/St_Johns' b'GMT-3:30'
# Timezone difference to GMT+0 -12600 s
# v8s
# Performing coord search
# Coordinates 48.400699615478516°N -123.52348327636719°E
# Elevation 6.0 m asl
# Timezone b'America/Vancouver' b'GMT-8'
# Timezone difference to GMT+0 -28800 s
# e4t
# Performing coord search
# Coordinates 46.2917366027832°N -64.98403930664062°E
# Elevation 95.0 m asl
# Timezone b'America/Moncton' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# s4h
# Performing coord search
# Coordinates -0.035149384289979935°N -78.36447143554688°E
# Elevation 2147.0 m asl
# Timezone b'America/Guayaquil' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# k1t
# Performing coord search
# Coordinates 45.30755615234375°N -75.65625°E
# Elevation 103.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# t8v
# Performing coord search
# Coordinates 55.149383544921875°N -118.79998779296875°E
# Elevation 661.0 m asl
# Timezone b'America/Edmonton' b'GMT-7'
# Timezone difference to GMT+0 -25200 s
# h7j
# Performing coord search
# Coordinates 45.65904998779297°N -73.70077514648438°E
# Elevation 39.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# n4k
# Performing coord search
# Coordinates 50.43936538696289°N 4.761904716491699°E
# Elevation 85.0 m asl
# Timezone b'Europe/Brussels' b'GMT+1'
# Timezone difference to GMT+0 3600 s
# j3h
# Performing coord search
# Coordinates 45.51845169067383°N -73.0455322265625°E
# Elevation 274.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# j5r
# Performing coord search
# Coordinates 45.44815444946289°N -73.49530029296875°E
# Elevation 12.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# t9c
# Performing coord search
# Coordinates 45.51845169067383°N 9.183672904968262°E
# Elevation 131.0 m asl
# Timezone b'Europe/Rome' b'GMT+1'
# Timezone difference to GMT+0 3600 s
# b2c
# Performing coord search
# Coordinates 46.01054382324219°N -60.85711669921875°E
# Elevation 53.0 m asl
# Timezone b'America/Glace_Bay' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# j7k
# Performing coord search
# Coordinates 45.79964828491211°N -73.6492919921875°E
# Elevation 32.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# p6a
# Performing coord search
# Coordinates 46.50263595581055°N -84.36599731445312°E
# Elevation 190.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# v3c
# Performing coord search
# Coordinates 52.12653732299805°N 1.4917126893997192°E
# Elevation 24.0 m asl
# Timezone b'Europe/London' None
# Timezone difference to GMT+0 0 s
# l5g
# Performing coord search
# Coordinates 43.550086975097656°N -79.57894897460938°E
# Elevation 93.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# e2p
# Performing coord search
# Coordinates 45.23725509643555°N -65.99066162109375°E
# Elevation 59.0 m asl
# Timezone b'America/Moncton' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# m2l
# Performing coord search
# Coordinates 43.760982513427734°N -79.395751953125°E
# Elevation 172.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# v6x
# Performing coord search
# Coordinates 49.173988342285156°N -123.07691955566406°E
# Elevation 3.0 m asl
# Timezone b'America/Vancouver' b'GMT-8'
# Timezone difference to GMT+0 -28800 s
# g6v
# Performing coord search
# Coordinates 46.78382873535156°N -71.24392700195312°E
# Elevation 86.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# e8k
# Performing coord search
# Coordinates 47.69771194458008°N -65.79208374023438°E
# Elevation 10.0 m asl
# Timezone b'America/Moncton' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# m5a
# Performing coord search
# Coordinates 43.620384216308594°N -79.56326293945312°E
# Elevation 86.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# s3n
# Performing coord search
# Coordinates 51.212650299072266°N -102.46401977539062°E
# Elevation 505.0 m asl
# Timezone b'America/Regina' b'GMT-6'
# Timezone difference to GMT+0 -21600 s
# n6k
# Performing coord search
# Coordinates 42.98769760131836°N -81.30758666992188°E
# Elevation 257.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# v5j
# Performing coord search
# Coordinates 49.173988342285156°N -122.92306518554688°E
# Elevation 6.0 m asl
# Timezone b'America/Vancouver' b'GMT-8'
# Timezone difference to GMT+0 -28800 s
# v2s
# Performing coord search
# Coordinates 47.69771194458008°N 16.633663177490234°E
# Elevation 215.0 m asl
# Timezone b'Europe/Budapest' b'GMT+1'
# Timezone difference to GMT+0 3600 s
# r2l
# Performing coord search
# Coordinates 49.876976013183594°N -97.04348754882812°E
# Elevation 231.0 m asl
# Timezone b'America/Winnipeg' b'GMT-6'
# Timezone difference to GMT+0 -21600 s
# p7l
# Performing coord search
# Coordinates 48.18980407714844°N -89.39898681640625°E
# Elevation 230.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# g8w
# Performing coord search
# Coordinates 46.432334899902344°N -72.54806518554688°E
# Elevation 66.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# n8m
# Performing coord search
# Coordinates 42.14411163330078°N -82.77371215820312°E
# Elevation 198.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# k9j
# Performing coord search
# Coordinates 44.32337188720703°N -78.302734375°E
# Elevation 276.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# r3g
# Performing coord search
# Coordinates 49.876976013183594°N -97.20001220703125°E
# Elevation 235.0 m asl
# Timezone b'America/Winnipeg' b'GMT-6'
# Timezone difference to GMT+0 -21600 s
# g9t
# Performing coord search
# Coordinates 46.64323043823242°N -72.75363159179688°E
# Elevation 152.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# g8z
# Performing coord search
# Coordinates 46.362037658691406°N -72.57601928710938°E
# Elevation 37.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# t1m
# Performing coord search
# Coordinates -33.427066802978516°N -70.7540283203125°E
# Elevation 476.0 m asl
# Timezone b'America/Santiago' b'GMT-3'
# Timezone difference to GMT+0 -10800 s
# r3m
# Performing coord search
# Coordinates 49.876976013183594°N -97.20001220703125°E
# Elevation 235.0 m asl
# Timezone b'America/Winnipeg' b'GMT-6'
# Timezone difference to GMT+0 -21600 s
# j8c
# Performing coord search
# Coordinates 46.080841064453125°N -74.2607421875°E
# Elevation 373.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# b1j
# Performing coord search
# Coordinates 46.01054382324219°N -60.428558349609375°E
# Elevation 161.0 m asl
# Timezone b'America/Glace_Bay' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# t8r
# Performing coord search
# Coordinates 53.81370544433594°N -113.58381652832031°E
# Elevation 702.0 m asl
# Timezone b'America/Edmonton' b'GMT-7'
# Timezone difference to GMT+0 -25200 s
# j5b
# Performing coord search
# Coordinates 45.37785339355469°N -73.5211181640625°E
# Elevation 29.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# m1r
# Performing coord search
# Coordinates 43.760982513427734°N -79.25979614257812°E
# Elevation 169.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# m1x
# Performing coord search
# Coordinates 43.83127975463867°N -79.24359130859375°E
# Elevation 156.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# e1a
# Performing coord search
# Coordinates 46.080841064453125°N -64.67410278320312°E
# Elevation 30.0 m asl
# Timezone b'America/Moncton' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# v5a
# Performing coord search
# Coordinates 52.12653732299805°N 1.4917126893997192°E
# Elevation 28.0 m asl
# Timezone b'Europe/London' None
# Timezone difference to GMT+0 0 s
# m6b
# Performing coord search
# Coordinates 43.6906852722168°N -79.4117431640625°E
# Elevation 174.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# k7m
# Performing coord search
# Coordinates 60.84358215332031°N 72.81623077392578°E
# Elevation 29.0 m asl
# Timezone b'Asia/Yekaterinburg' b'GMT+5'
# Timezone difference to GMT+0 18000 s
# g6h
# Performing coord search
# Coordinates 46.080841064453125°N -71.3990478515625°E
# Elevation 434.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# j1a
# Performing coord search
# Coordinates 45.16695785522461°N -71.77569580078125°E
# Elevation 288.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# k2p
# Performing coord search
# Coordinates 45.44815444946289°N -75.75234985351562°E
# Elevation 72.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# e8s
# Performing coord search
# Coordinates 47.76801300048828°N -64.8594970703125°E
# Elevation 0.0 m asl
# Timezone b'America/Moncton' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# k3v
# Performing coord search
# Coordinates 44.46397018432617°N 7.453987121582031°E
# Elevation 651.0 m asl
# Timezone b'Europe/Rome' b'GMT+1'
# Timezone difference to GMT+0 3600 s
# t6v
# Performing coord search
# Coordinates 53.60280990600586°N -113.62068176269531°E
# Elevation 685.0 m asl
# Timezone b'America/Edmonton' b'GMT-7'
# Timezone difference to GMT+0 -25200 s
# j3l
# Performing coord search
# Coordinates 47.205623626708984°N 6.7536702156066895°E
# Elevation 856.0 m asl
# Timezone b'Europe/Paris' b'GMT+1'
# Timezone difference to GMT+0 3600 s
# l1k
# Performing coord search
# Coordinates 43.901580810546875°N -78.81817626953125°E
# Elevation 158.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# c0q
# Performing coord search
# Coordinates 37.152896881103516°N -96.30950927734375°E
# Elevation 260.0 m asl
# Timezone b'America/Chicago' b'GMT-6'
# Timezone difference to GMT+0 -21600 s
# t7p
# Performing coord search
# Coordinates 54.165199279785156°N -113.813232421875°E
# Elevation 657.0 m asl
# Timezone b'America/Edmonton' b'GMT-7'
# Timezone difference to GMT+0 -25200 s
# n3c
# Performing coord search
# Coordinates -0.1054481565952301°N -78.42556762695312°E
# Elevation 2697.0 m asl
# Timezone b'America/Guayaquil' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# n6g
# Performing coord search
# Coordinates -0.1054481565952301°N -78.42556762695312°E
# Elevation 2679.0 m asl
# Timezone b'America/Guayaquil' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# g5v
# Performing coord search
# Coordinates 46.99472427368164°N -70.56820678710938°E
# Elevation 16.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# l0b
# Performing coord search
# Coordinates 44.042179107666016°N -78.7841796875°E
# Elevation 315.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# t6h
# Performing coord search
# Coordinates 53.39191436767578°N -113.48570251464844°E
# Elevation 704.0 m asl
# Timezone b'America/Edmonton' b'GMT-7'
# Timezone difference to GMT+0 -25200 s
# p7j
# Performing coord search
# Coordinates 48.26010513305664°N -89.39801025390625°E
# Elevation 274.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# s0e
# Performing coord search
# Coordinates 53.1107177734375°N -103.10018920898438°E
# Elevation 485.0 m asl
# Timezone b'America/Regina' b'GMT-6'
# Timezone difference to GMT+0 -21600 s
# e1h
# Performing coord search
# Coordinates 46.15114212036133°N -64.63375854492188°E
# Elevation 46.0 m asl
# Timezone b'America/Moncton' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# t3k
# Performing coord search
# Coordinates 21.8980655670166°N 96.19732666015625°E
# Elevation 86.0 m asl
# Timezone b'Asia/Yangon' b'GMT+6:30'
# Timezone difference to GMT+0 23400 s
# j0m
# Performing coord search
# Coordinates 58.312828063964844°N -72.19778442382812°E
# Elevation 219.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# n9y
# Performing coord search
# Coordinates 42.07381057739258°N -82.78424072265625°E
# Elevation 194.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# k2s
# Performing coord search
# Coordinates 45.23725509643555°N -75.95944213867188°E
# Elevation 126.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# l2a
# Performing coord search
# Coordinates 42.917396545410156°N -78.91693115234375°E
# Elevation 186.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# n7w
# Performing coord search
# Coordinates 42.98769760131836°N -82.37744140625°E
# Elevation 184.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# e2l
# Performing coord search
# Coordinates 45.23725509643555°N -65.99066162109375°E
# Elevation 33.0 m asl
# Timezone b'America/Moncton' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# g6w
# Performing coord search
# Coordinates 46.78382873535156°N -71.24392700195312°E
# Elevation 48.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# j1n
# Performing coord search
# Coordinates 45.30755615234375°N -72.0°E
# Elevation 193.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# j8a
# Performing coord search
# Coordinates 45.940242767333984°N -74.02536010742188°E
# Elevation 250.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# p4a
# Performing coord search
# Coordinates 8.541300773620605°N -81.1005859375°E
# Elevation 650.0 m asl
# Timezone b'America/Panama' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# t4v
# Performing coord search
# Coordinates 53.04042053222656°N -112.75471496582031°E
# Elevation 738.0 m asl
# Timezone b'America/Edmonton' b'GMT-7'
# Timezone difference to GMT+0 -25200 s
# b3v
# Performing coord search
# Coordinates 44.53426742553711°N -63.594482421875°E
# Elevation 89.0 m asl
# Timezone b'America/Halifax' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# e5n
# Performing coord search
# Coordinates 45.51845169067383°N -65.83987426757812°E
# Elevation -1.0 m asl
# Timezone b'America/Moncton' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# l1y
# Performing coord search
# Coordinates 43.97187805175781°N -79.07437133789062°E
# Elevation 250.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# l1z
# Performing coord search
# Coordinates 43.901580810546875°N -78.95452880859375°E
# Elevation 100.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# k9a
# Performing coord search
# Coordinates 51.77504348754883°N 19.54379653930664°E
# Elevation 222.0 m asl
# Timezone b'Europe/Warsaw' b'GMT+1'
# Timezone difference to GMT+0 3600 s
# b0k
# Performing coord search
# Coordinates 45.588748931884766°N -62.971710205078125°E
# Elevation 241.0 m asl
# Timezone b'America/Halifax' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# m8v
# Performing coord search
# Coordinates 43.620384216308594°N -79.56326293945312°E
# Elevation 90.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# j4b
# Performing coord search
# Coordinates 45.588748931884766°N -73.44342041015625°E
# Elevation 19.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# j3y
# Performing coord search
# Coordinates 45.51845169067383°N -73.46939086914062°E
# Elevation 23.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# t2e
# Performing coord search
# Coordinates 51.07205581665039°N -114.03227233886719°E
# Elevation 1077.0 m asl
# Timezone b'America/Edmonton' b'GMT-7'
# Timezone difference to GMT+0 -25200 s
# v9r
# Performing coord search
# Coordinates 49.173988342285156°N -123.99998474121094°E
# Elevation 222.0 m asl
# Timezone b'America/Vancouver' b'GMT-8'
# Timezone difference to GMT+0 -28800 s
# h1r
# Performing coord search
# Coordinates 45.588748931884766°N -73.58493041992188°E
# Elevation 43.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# l0w
# Performing coord search
# Coordinates 53.1810188293457°N 50.28409194946289°E
# Elevation 137.0 m asl
# Timezone b'Europe/Samara' b'GMT+4'
# Timezone difference to GMT+0 14400 s
# l6r
# Performing coord search
# Coordinates 43.760982513427734°N -79.80361938476562°E
# Elevation 240.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# v9p
# Performing coord search
# Coordinates 49.3145866394043°N -124.27101135253906°E
# Elevation 40.0 m asl
# Timezone b'America/Vancouver' b'GMT-8'
# Timezone difference to GMT+0 -28800 s
# t0j
# Performing coord search
# Coordinates 51.49384689331055°N -112.66304016113281°E
# Elevation 687.0 m asl
# Timezone b'America/Edmonton' b'GMT-7'
# Timezone difference to GMT+0 -25200 s
# e3m
# Performing coord search
# Coordinates -4.18277645111084°N 139.88571166992188°E
# Elevation 927.0 m asl
# Timezone b'Asia/Jayapura' b'GMT+9'
# Timezone difference to GMT+0 32400 s
# v9g
# Performing coord search
# Coordinates 48.96309280395508°N -123.82652282714844°E
# Elevation 82.0 m asl
# Timezone b'America/Vancouver' b'GMT-8'
# Timezone difference to GMT+0 -28800 s
# v7v
# Performing coord search
# Coordinates 49.3145866394043°N -123.03602600097656°E
# Elevation 70.0 m asl
# Timezone b'America/Vancouver' b'GMT-8'
# Timezone difference to GMT+0 -28800 s
# n6n
# Performing coord search
# Coordinates -0.1054481565952301°N -78.42556762695312°E
# Elevation 2718.0 m asl
# Timezone b'America/Guayaquil' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# e4x
# Performing coord search
# Coordinates 46.713531494140625°N -65.03225708007812°E
# Elevation 19.0 m asl
# Timezone b'America/Moncton' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# b3g
# Performing coord search
# Coordinates 44.60456848144531°N -63.5538330078125°E
# Elevation 29.0 m asl
# Timezone b'America/Halifax' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# k1k
# Performing coord search
# Coordinates 45.44815444946289°N -75.61126708984375°E
# Elevation 90.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# e5p
# Performing coord search
# Coordinates 45.729347229003906°N -65.72555541992188°E
# Elevation 42.0 m asl
# Timezone b'America/Moncton' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# g7b
# Performing coord search
# Coordinates 48.33040237426758°N -70.85427856445312°E
# Elevation 27.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# p0l
# Performing coord search
# Coordinates 51.985939025878906°N -83.55963134765625°E
# Elevation 75.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# j4v
# Performing coord search
# Coordinates 45.51845169067383°N -73.46939086914062°E
# Elevation 21.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# v3g
# Performing coord search
# Coordinates 49.10368728637695°N -122.2525634765625°E
# Elevation 186.0 m asl
# Timezone b'America/Vancouver' b'GMT-8'
# Timezone difference to GMT+0 -28800 s
# b1v
# Performing coord search
# Coordinates 46.221439361572266°N -60.287078857421875°E
# Elevation 23.0 m asl
# Timezone b'America/Glace_Bay' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# l2m
# Performing coord search
# Coordinates 49.10368728637695°N -1.38226318359375°E
# Elevation 126.0 m asl
# Timezone b'Europe/Paris' b'GMT+1'
# Timezone difference to GMT+0 3600 s
# j2s
# Performing coord search
# Coordinates 45.588748931884766°N -73.01889038085938°E
# Elevation 44.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# v6n
# Performing coord search
# Coordinates 49.244285583496094°N -123.13357543945312°E
# Elevation 14.0 m asl
# Timezone b'America/Vancouver' b'GMT-8'
# Timezone difference to GMT+0 -28800 s
# j3t
# Performing coord search
# Coordinates 40.808433532714844°N -92.68466186523438°E
# Elevation 294.0 m asl
# Timezone b'America/Chicago' b'GMT-6'
# Timezone difference to GMT+0 -21600 s
# r4j
# Performing coord search
# Coordinates 49.876976013183594°N -97.35653686523438°E
# Elevation 237.0 m asl
# Timezone b'America/Winnipeg' b'GMT-6'
# Timezone difference to GMT+0 -21600 s
# l1p
# Performing coord search
# Coordinates 43.901580810546875°N -78.95452880859375°E
# Elevation 103.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# e1c
# Performing coord search
# Coordinates 46.080841064453125°N -64.81716918945312°E
# Elevation 35.0 m asl
# Timezone b'America/Moncton' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# n0k
# Performing coord search
# Coordinates 43.47978591918945°N -81.21621704101562°E
# Elevation 349.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# p3a
# Performing coord search
# Coordinates 46.50263595581055°N -80.89889526367188°E
# Elevation 267.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# g0r
# Performing coord search
# Coordinates 46.78382873535156°N -70.37155151367188°E
# Elevation 503.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# n8h
# Performing coord search
# Coordinates 51.14235305786133°N 2.7468581199645996°E
# Elevation 6.0 m asl
# Timezone b'Europe/Brussels' b'GMT+1'
# Timezone difference to GMT+0 3600 s
# j4r
# Performing coord search
# Coordinates 14.657293319702148°N 121.03160095214844°E
# Elevation 75.0 m asl
# Timezone b'Asia/Manila' b'GMT+8'
# Timezone difference to GMT+0 28800 s
# v4m
# Performing coord search
# Coordinates 49.033390045166016°N -123.11753845214844°E
# Elevation 2.0 m asl
# Timezone b'America/Vancouver' b'GMT-8'
# Timezone difference to GMT+0 -28800 s
# g0z
# Performing coord search
# Coordinates 46.15114212036133°N -72.08599853515625°E
# Elevation 98.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# g7g
# Performing coord search
# Coordinates 48.47100067138672°N -71.09243774414062°E
# Elevation 82.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# t1j
# Performing coord search
# Coordinates 49.666080474853516°N -112.73356628417969°E
# Elevation 918.0 m asl
# Timezone b'America/Edmonton' b'GMT-7'
# Timezone difference to GMT+0 -25200 s
# v7w
# Performing coord search
# Coordinates 49.384883880615234°N -123.2474365234375°E
# Elevation 91.0 m asl
# Timezone b'America/Vancouver' b'GMT-8'
# Timezone difference to GMT+0 -28800 s
# n1t
# Performing coord search
# Coordinates 43.409488677978516°N -80.28485107421875°E
# Elevation 318.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# l5e
# Performing coord search
# Coordinates 43.550086975097656°N -79.57894897460938°E
# Elevation 96.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# v6a
# Performing coord search
# Coordinates 49.244285583496094°N -123.13357543945312°E
# Elevation 22.0 m asl
# Timezone b'America/Vancouver' b'GMT-8'
# Timezone difference to GMT+0 -28800 s
# v7a
# Performing coord search
# Coordinates 52.12653732299805°N 1.4917126893997192°E
# Elevation 27.0 m asl
# Timezone b'Europe/London' None
# Timezone difference to GMT+0 0 s
# j7j
# Performing coord search
# Coordinates 45.729347229003906°N -73.958984375°E
# Elevation 69.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# n2z
# Performing coord search
# Coordinates 44.18277359008789°N -81.631103515625°E
# Elevation 217.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# h3j
# Performing coord search
# Coordinates 45.51845169067383°N -73.61068725585938°E
# Elevation 20.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# n0m
# Performing coord search
# Coordinates 43.268890380859375°N -81.524658203125°E
# Elevation 255.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# j8x
# Performing coord search
# Coordinates 45.44815444946289°N -75.75234985351562°E
# Elevation 48.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# t1k
# Performing coord search
# Coordinates 49.666080474853516°N -112.8892822265625°E
# Elevation 907.0 m asl
# Timezone b'America/Edmonton' b'GMT-7'
# Timezone difference to GMT+0 -25200 s
# r3c
# Performing coord search
# Coordinates 50.017574310302734°N -97.22512817382812°E
# Elevation 232.0 m asl
# Timezone b'America/Winnipeg' b'GMT-6'
# Timezone difference to GMT+0 -21600 s
# j6g
# Performing coord search
# Coordinates 7.978910446166992°N 31.972673416137695°E
# Elevation 403.0 m asl
# Timezone b'Africa/Juba' b'GMT+2'
# Timezone difference to GMT+0 7200 s
# v8c
# Performing coord search
# Coordinates 52.12653732299805°N 1.4917126893997192°E
# Elevation 20.0 m asl
# Timezone b'Europe/London' None
# Timezone difference to GMT+0 0 s
# v3a
# Performing coord search
# Coordinates 29.209136962890625°N 32.62370300292969°E
# Elevation 4.0 m asl
# Timezone b'Africa/Cairo' b'GMT+2'
# Timezone difference to GMT+0 7200 s
# l0c
# Performing coord search
# Coordinates 44.18277359008789°N -79.02438354492188°E
# Elevation 260.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# j1g
# Performing coord search
# Coordinates 45.37785339355469°N -71.83096313476562°E
# Elevation 210.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# e4z
# Performing coord search
# Coordinates 45.940242767333984°N -65.1822509765625°E
# Elevation 32.0 m asl
# Timezone b'America/Moncton' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# l7z
# Performing coord search
# Coordinates 46.9244270324707°N 12.544569969177246°E
# Elevation 1646.0 m asl
# Timezone b'Europe/Vienna' b'GMT+1'
# Timezone difference to GMT+0 3600 s
# g3m
# Performing coord search
# Coordinates 46.713531494140625°N -71.70968627929688°E
# Elevation 62.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# j0r
# Performing coord search
# Coordinates 45.86994552612305°N -74.19302368164062°E
# Elevation 353.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# l7j
# Performing coord search
# Coordinates 43.620384216308594°N -80.10540771484375°E
# Elevation 349.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# l8t
# Performing coord search
# Coordinates 43.19859313964844°N -79.791015625°E
# Elevation 190.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# j8m
# Performing coord search
# Coordinates 45.51845169067383°N -75.44741821289062°E
# Elevation 56.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# v3y
# Performing coord search
# Coordinates 49.244285583496094°N -122.82534790039062°E
# Elevation 10.0 m asl
# Timezone b'America/Vancouver' b'GMT-8'
# Timezone difference to GMT+0 -28800 s
# s4v
# Performing coord search
# Coordinates 50.43936538696289°N -104.60316467285156°E
# Elevation 579.0 m asl
# Timezone b'America/Regina' b'GMT-6'
# Timezone difference to GMT+0 -21600 s
# g4h
# Performing coord search
# Coordinates 8.049209594726562°N -1.076904296875°E
# Elevation 113.0 m asl
# Timezone b'Africa/Accra' None
# Timezone difference to GMT+0 0 s
# b0w
# Performing coord search
# Coordinates 44.042179107666016°N -65.790283203125°E
# Elevation 113.0 m asl
# Timezone b'America/Halifax' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# e1m
# Performing coord search
# Coordinates -4.18277645111084°N 139.88571166992188°E
# Elevation 927.0 m asl
# Timezone b'Asia/Jayapura' b'GMT+9'
# Timezone difference to GMT+0 32400 s
# v2l
# Performing coord search
# Coordinates 25.27240562438965°N 51.56756591796875°E
# Elevation 3.0 m asl
# Timezone b'Asia/Qatar' b'GMT+3'
# Timezone difference to GMT+0 10800 s
# t2l
# Performing coord search
# Coordinates 51.07205581665039°N -114.19355773925781°E
# Elevation 1200.0 m asl
# Timezone b'America/Edmonton' b'GMT-7'
# Timezone difference to GMT+0 -25200 s
# g5y
# Performing coord search
# Coordinates 46.15114212036133°N -70.65286254882812°E
# Elevation 281.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# n4r
# Performing coord search
# Coordinates -0.5272407531738281°N 166.9616241455078°E
# Elevation 36.0 m asl
# Timezone b'Pacific/Nauru' b'GMT+12'
# Timezone difference to GMT+0 43200 s
# j1b
# Performing coord search
# Coordinates 1.441124677658081°N 103.7420883178711°E
# Elevation 9.0 m asl
# Timezone b'Asia/Kuala_Lumpur' b'GMT+8'
# Timezone difference to GMT+0 28800 s
# g8b
# Performing coord search
# Coordinates 48.541297912597656°N -71.66665649414062°E
# Elevation 116.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# e2k
# Performing coord search
# Coordinates 45.30755615234375°N -66.09375°E
# Elevation 74.0 m asl
# Timezone b'America/Moncton' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# g1n
# Performing coord search
# Coordinates 46.78382873535156°N -71.24392700195312°E
# Elevation 18.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# h3c
# Performing coord search
# Coordinates 45.51845169067383°N -73.61068725585938°E
# Elevation 13.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# m6s
# Performing coord search
# Coordinates 43.620384216308594°N -79.56326293945312°E
# Elevation 118.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# p3l
# Performing coord search
# Coordinates 46.572933197021484°N -80.88424682617188°E
# Elevation 293.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# h2s
# Performing coord search
# Coordinates 45.51845169067383°N -73.61068725585938°E
# Elevation 65.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# l8k
# Performing coord search
# Coordinates 43.19859313964844°N -79.791015625°E
# Elevation 98.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# e5c
# Performing coord search
# Coordinates 45.09666061401367°N -66.76513671875°E
# Elevation 30.0 m asl
# Timezone b'America/Moncton' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# v7s
# Performing coord search
# Coordinates 49.384883880615234°N -123.09278869628906°E
# Elevation 936.0 m asl
# Timezone b'America/Vancouver' b'GMT-8'
# Timezone difference to GMT+0 -28800 s
# s9h
# Performing coord search
# Coordinates -0.035149384289979935°N -78.4345703125°E
# Elevation 2535.0 m asl
# Timezone b'America/Guayaquil' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# h8s
# Performing coord search
# Coordinates 45.44815444946289°N -73.6363525390625°E
# Elevation 24.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# v4n
# Performing coord search
# Coordinates 46.854129791259766°N 6.844660758972168°E
# Elevation 462.0 m asl
# Timezone b'Europe/Zurich' b'GMT+1'
# Timezone difference to GMT+0 3600 s
# t2m
# Performing coord search
# Coordinates 45.729347229003906°N 4.968454360961914°E
# Elevation 207.0 m asl
# Timezone b'Europe/Paris' b'GMT+1'
# Timezone difference to GMT+0 3600 s
# k0v
# Performing coord search
# Coordinates 44.46397018432617°N 7.453987121582031°E
# Elevation 651.0 m asl
# Timezone b'Europe/Rome' b'GMT+1'
# Timezone difference to GMT+0 3600 s
# l6p
# Performing coord search
# Coordinates 43.760982513427734°N -79.66766357421875°E
# Elevation 205.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# b1e
# Performing coord search
# Coordinates 41.3005256652832°N -85.7388916015625°E
# Elevation 273.0 m asl
# Timezone b'America/Indiana/Indianapolis' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# t4b
# Performing coord search
# Coordinates 51.28295135498047°N -114.00001525878906°E
# Elevation 1083.0 m asl
# Timezone b'America/Edmonton' b'GMT-7'
# Timezone difference to GMT+0 -25200 s
# m4p
# Performing coord search
# Coordinates 43.6906852722168°N -79.4117431640625°E
# Elevation 164.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# j5m
# Performing coord search
# Coordinates 45.86994552612305°N -73.76583862304688°E
# Elevation 59.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# j9v
# Performing coord search
# Coordinates 13.813708305358887°N -89.090087890625°E
# Elevation 563.0 m asl
# Timezone b'America/El_Salvador' b'GMT-6'
# Timezone difference to GMT+0 -21600 s
# r8a
# Performing coord search
# Coordinates 54.797889709472656°N -101.94058227539062°E
# Elevation 310.0 m asl
# Timezone b'America/Winnipeg' b'GMT-6'
# Timezone difference to GMT+0 -21600 s
# l6j
# Performing coord search
# Coordinates 43.47978591918945°N -79.729736328125°E
# Elevation 102.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# l7b
# Performing coord search
# Coordinates 43.901580810546875°N -79.5°E
# Elevation 304.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# t5m
# Performing coord search
# Coordinates 43.83127975463867°N 15.930408477783203°E
# Elevation 120.0 m asl
# Timezone b'Europe/Zagreb' b'GMT+1'
# Timezone difference to GMT+0 3600 s
# n4g
# Performing coord search
# Coordinates -0.1054481565952301°N -78.42556762695312°E
# Elevation 2677.0 m asl
# Timezone b'America/Guayaquil' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# v2t
# Performing coord search
# Coordinates 49.033390045166016°N -122.35092163085938°E
# Elevation 82.0 m asl
# Timezone b'America/Vancouver' b'GMT-8'
# Timezone difference to GMT+0 -28800 s
# m9b
# Performing coord search
# Coordinates 43.620384216308594°N -79.56326293945312°E
# Elevation 147.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# r7c
# Performing coord search
# Coordinates 49.876976013183594°N -100.01739501953125°E
# Elevation 402.0 m asl
# Timezone b'America/Winnipeg' b'GMT-6'
# Timezone difference to GMT+0 -21600 s
# s0k
# Performing coord search
# Coordinates 52.26713180541992°N -106.46951293945312°E
# Elevation 475.0 m asl
# Timezone b'America/Regina' b'GMT-6'
# Timezone difference to GMT+0 -21600 s
# n2c
# Performing coord search
# Coordinates -0.17574693262577057°N -78.34634399414062°E
# Elevation 2554.0 m asl
# Timezone b'America/Guayaquil' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# v0l
# Performing coord search
# Coordinates 52.056236267089844°N -125.73530578613281°E
# Elevation 1501.0 m asl
# Timezone b'America/Vancouver' b'GMT-8'
# Timezone difference to GMT+0 -28800 s
# p5a
# Performing coord search
# Coordinates 46.362037658691406°N -82.656005859375°E
# Elevation 310.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# v6l
# Performing coord search
# Coordinates 49.244285583496094°N -123.13357543945312°E
# Elevation 38.0 m asl
# Timezone b'America/Vancouver' b'GMT-8'
# Timezone difference to GMT+0 -28800 s
# t6j
# Performing coord search
# Coordinates 53.46221160888672°N -113.53053283691406°E
# Elevation 678.0 m asl
# Timezone b'America/Edmonton' b'GMT-7'
# Timezone difference to GMT+0 -25200 s
# p1a
# Performing coord search
# Coordinates 46.2917366027832°N -79.36102294921875°E
# Elevation 193.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# l8l
# Performing coord search
# Coordinates 43.268890380859375°N -79.91030883789062°E
# Elevation 74.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# p0n
# Performing coord search
# Coordinates 48.61159896850586°N -81.0455322265625°E
# Elevation 303.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# b3b
# Performing coord search
# Coordinates 28.646747589111328°N 77.0695571899414°E
# Elevation 220.0 m asl
# Timezone b'Asia/Kolkata' b'GMT+5:30'
# Timezone difference to GMT+0 19800 s
# h9e
# Performing coord search
# Coordinates 45.51845169067383°N -73.89324951171875°E
# Elevation 61.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# k6h
# Performing coord search
# Coordinates 45.02635955810547°N -74.6273193359375°E
# Elevation 62.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# h4m
# Performing coord search
# Coordinates 45.51845169067383°N -73.751953125°E
# Elevation 39.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# n8e
# Performing coord search
# Coordinates -0.035149384289979935°N -78.50466918945312°E
# Elevation 2781.0 m asl
# Timezone b'America/Guayaquil' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# p9a
# Performing coord search
# Coordinates 48.61159896850586°N -93.33895874023438°E
# Elevation 335.0 m asl
# Timezone b'America/Chicago' b'GMT-6'
# Timezone difference to GMT+0 -21600 s
# b0j
# Performing coord search
# Coordinates 44.81546401977539°N -63.2921142578125°E
# Elevation 13.0 m asl
# Timezone b'America/Halifax' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# j3a
# Performing coord search
# Coordinates 45.30755615234375°N -73.265625°E
# Elevation 34.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# t8a
# Performing coord search
# Coordinates 53.53251266479492°N -113.23136901855469°E
# Elevation 719.0 m asl
# Timezone b'America/Edmonton' b'GMT-7'
# Timezone difference to GMT+0 -25200 s
# l7l
# Performing coord search
# Coordinates 43.409488677978516°N -79.7451171875°E
# Elevation 114.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# n5p
# Performing coord search
# Coordinates 42.776798248291016°N -81.2130126953125°E
# Elevation 233.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# e8r
# Performing coord search
# Coordinates 47.62741470336914°N -65.2388916015625°E
# Elevation 56.0 m asl
# Timezone b'America/Moncton' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# t4n
# Performing coord search
# Coordinates 3.198593854904175°N 12.85714340209961°E
# Elevation 681.0 m asl
# Timezone b'Africa/Douala' b'GMT+1'
# Timezone difference to GMT+0 3600 s
# l9p
# Performing coord search
# Coordinates 44.11247634887695°N -79.17807006835938°E
# Elevation 278.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# v3e
# Performing coord search
# Coordinates 49.3145866394043°N -122.57289123535156°E
# Elevation 546.0 m asl
# Timezone b'America/Vancouver' b'GMT-8'
# Timezone difference to GMT+0 -28800 s
# n7l
# Performing coord search
# Coordinates 42.4253044128418°N -82.20263671875°E
# Elevation 181.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# b4z
# Performing coord search
# Coordinates 17.11775016784668°N -88.70318603515625°E
# Elevation 209.0 m asl
# Timezone b'America/Belize' b'GMT-6'
# Timezone difference to GMT+0 -21600 s
# g9h
# Performing coord search
# Coordinates 46.362037658691406°N -72.4320068359375°E
# Elevation 11.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# n8r
# Performing coord search
# Coordinates 42.28470993041992°N -82.88433837890625°E
# Elevation 183.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# h1n
# Performing coord search
# Coordinates 45.588748931884766°N -73.58493041992188°E
# Elevation 21.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# h7l
# Performing coord search
# Coordinates 45.588748931884766°N -73.7264404296875°E
# Elevation 30.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# j8b
# Performing coord search
# Coordinates 45.940242767333984°N -74.16799926757812°E
# Elevation 241.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# g6t
# Performing coord search
# Coordinates 46.080841064453125°N -71.97137451171875°E
# Elevation 145.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# j3z
# Performing coord search
# Coordinates 45.51845169067383°N -73.32809448242188°E
# Elevation 24.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# t3h
# Performing coord search
# Coordinates 51.07205581665039°N -114.19355773925781°E
# Elevation 1212.0 m asl
# Timezone b'America/Edmonton' b'GMT-7'
# Timezone difference to GMT+0 -25200 s
# g9x
# Performing coord search
# Coordinates 47.41651916503906°N -72.88525390625°E
# Elevation 169.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# t1w
# Performing coord search
# ...
# Timezone difference to GMT+0 -14400 s
# t4s
# Performing coord search
# Coordinates 3.198593854904175°N 12.85714340209961°E
# Elevation 707.0 m asl
# Timezone b'Africa/Douala' b'GMT+1'
# Timezone difference to GMT+0 3600 s
# m1w
# Performing coord search
# Coordinates 43.83127975463867°N -79.37973022460938°E
# Elevation 183.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# l8v
# Performing coord search
# Coordinates 43.19859313964844°N -79.791015625°E
# Elevation 202.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# b9a
# Performing coord search
# Coordinates 45.588748931884766°N -61.41510009765625°E
# Elevation 40.0 m asl
# Timezone b'America/Glace_Bay' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# n8w
# Performing coord search
# Coordinates 42.28470993041992°N -83.01611328125°E
# Elevation 196.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# v2c
# Performing coord search
# Coordinates 52.12653732299805°N 1.4917126893997192°E
# Elevation 23.0 m asl
# Timezone b'Europe/London' None
# Timezone difference to GMT+0 0 s
# g6x
# Performing coord search
# Coordinates 46.713531494140625°N -71.27420043945312°E
# Elevation 72.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# a0b
# Performing coord search
# Coordinates 47.34621810913086°N -53.61700439453125°E
# Elevation 169.0 m asl
# Timezone b'America/St_Johns' b'GMT-3:30'
# Timezone difference to GMT+0 -12600 s
# b4b
# Performing coord search
# Coordinates 50.017574310302734°N 19.947643280029297°E
# Elevation 226.0 m asl
# Timezone b'Europe/Warsaw' b'GMT+1'
# Timezone difference to GMT+0 3600 s
# g0e
# Performing coord search
# Coordinates 48.892791748046875°N -65.39895629882812°E
# Elevation 542.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# e7g
# Performing coord search
# Coordinates 46.9244270324707°N -67.39059448242188°E
# Elevation 148.0 m asl
# Timezone b'America/Moncton' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# g3g
# Performing coord search
# Coordinates 46.9244270324707°N -71.32901000976562°E
# Elevation 171.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# l6e
# Performing coord search
# Coordinates 43.901580810546875°N -79.22726440429688°E
# Elevation 210.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# l9e
# Performing coord search
# Coordinates 40.17574691772461°N 18.176719665527344°E
# Elevation 79.0 m asl
# Timezone b'Europe/Rome' b'GMT+1'
# Timezone difference to GMT+0 3600 s
# r2w
# Performing coord search
# Coordinates 49.94727325439453°N -97.2125244140625°E
# Elevation 235.0 m asl
# Timezone b'America/Winnipeg' b'GMT-6'
# Timezone difference to GMT+0 -21600 s
# g9a
# Performing coord search
# Coordinates 41.3005256652832°N 28.79483413696289°E
# Elevation 95.0 m asl
# Timezone b'Europe/Istanbul' b'GMT+3'
# Timezone difference to GMT+0 10800 s
# v3z
# Performing coord search
# Coordinates -34.62214279174805°N -58.409088134765625°E
# Elevation 27.0 m asl
# Timezone b'America/Argentina/Buenos_Aires' b'GMT-3'
# Timezone difference to GMT+0 -10800 s
# n1l
# Performing coord search
# Coordinates 43.550086975097656°N -80.255615234375°E
# Elevation 338.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# v4z
# Performing coord search
# Coordinates 49.10368728637695°N -121.79180908203125°E
# Elevation 859.0 m asl
# Timezone b'America/Vancouver' b'GMT-8'
# Timezone difference to GMT+0 -28800 s
# v6j
# Performing coord search
# Coordinates 49.244285583496094°N -123.13357543945312°E
# Elevation 45.0 m asl
# Timezone b'America/Vancouver' b'GMT-8'
# Timezone difference to GMT+0 -28800 s
# t1g
# Performing coord search
# Coordinates 49.80667495727539°N -112.1875°E
# Elevation 814.0 m asl
# Timezone b'America/Edmonton' b'GMT-7'
# Timezone difference to GMT+0 -25200 s
# e8n
# Performing coord search
# Coordinates 47.83831024169922°N -65.264892578125°E
# Elevation 24.0 m asl
# Timezone b'America/Moncton' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# g0y
# Performing coord search
# Coordinates 45.65904998779297°N -71.00787353515625°E
# Elevation 537.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# l3z
# Performing coord search
# Coordinates 44.11247634887695°N -79.58905029296875°E
# Elevation 254.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# g5z
# Performing coord search
# Coordinates 46.080841064453125°N -70.68362426757812°E
# Elevation 322.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# l9j
# Performing coord search
# Coordinates 44.32337188720703°N -79.67889404296875°E
# Elevation 257.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# h3z
# Performing coord search
# Coordinates 45.44815444946289°N -73.6363525390625°E
# Elevation 57.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# l5j
# Performing coord search
# Coordinates 43.47978591918945°N -79.729736328125°E
# Elevation 98.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# t2z
# Performing coord search
# Coordinates 50.93145751953125°N -113.94642639160156°E
# Elevation 1039.0 m asl
# Timezone b'America/Edmonton' b'GMT-7'
# Timezone difference to GMT+0 -25200 s
# l7t
# Performing coord search
# Coordinates 43.33919143676758°N -79.89523315429688°E
# Elevation 102.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# j7c
# Performing coord search
# Coordinates 45.65904998779297°N -73.84249877929688°E
# Elevation 79.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# l2v
# Performing coord search
# Coordinates 43.128292083740234°N -79.26974487304688°E
# Elevation 179.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# j0j
# Performing coord search
# Coordinates 45.16695785522461°N -73.17755126953125°E
# Elevation 34.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# b2p
# Performing coord search
# Coordinates 49.3145866394043°N 4.16809606552124°E
# Elevation 147.0 m asl
# Timezone b'Europe/Paris' b'GMT+1'
# Timezone difference to GMT+0 3600 s
# e5j
# Performing coord search
# Coordinates 45.16695785522461°N -66.44857788085938°E
# Elevation 41.0 m asl
# Timezone b'America/Moncton' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# h9j
# Performing coord search
# Coordinates 45.44815444946289°N -73.91848754882812°E
# Elevation 41.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# s0c
# Performing coord search
# Coordinates 49.384883880615234°N -103.29898071289062°E
# Elevation 590.0 m asl
# Timezone b'America/Regina' b'GMT-6'
# Timezone difference to GMT+0 -21600 s
# l7c
# Performing coord search
# Coordinates 43.901580810546875°N -79.90908813476562°E
# Elevation 294.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# b1s
# Performing coord search
# Coordinates 46.080841064453125°N -60.238494873046875°E
# Elevation 50.0 m asl
# Timezone b'America/Glace_Bay' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# n1h
# Performing coord search
# Coordinates -0.24604569375514984°N -78.40750122070312°E
# Elevation 2571.0 m asl
# Timezone b'America/Guayaquil' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# v4s
# Performing coord search
# Coordinates 49.244285583496094°N -122.51713562011719°E
# Elevation 78.0 m asl
# Timezone b'America/Vancouver' b'GMT-8'
# Timezone difference to GMT+0 -28800 s
# r2r
# Performing coord search
# Coordinates 49.94727325439453°N -97.2125244140625°E
# Elevation 237.0 m asl
# Timezone b'America/Winnipeg' b'GMT-6'
# Timezone difference to GMT+0 -21600 s
# n8t
# Performing coord search
# Coordinates 42.28470993041992°N -82.88433837890625°E
# Elevation 184.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# v4k
# Performing coord search
# Coordinates 49.10368728637695°N -123.02047729492188°E
# Elevation 1.0 m asl
# Timezone b'America/Vancouver' b'GMT-8'
# Timezone difference to GMT+0 -28800 s
# a1y
# Performing coord search
# Coordinates 47.69771194458008°N -53.31683349609375°E
# Elevation 127.0 m asl
# Timezone b'America/St_Johns' b'GMT-3:30'
# Timezone difference to GMT+0 -12600 s
# e3y
# Performing coord search
# Coordinates 47.13532257080078°N -67.57330322265625°E
# Elevation 291.0 m asl
# Timezone b'America/Moncton' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# e8m
# Performing coord search
# Coordinates 47.5571174621582°N -65.13156127929688°E
# Elevation 54.0 m asl
# Timezone b'America/Moncton' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# k1r
# Performing coord search
# Coordinates 45.37785339355469°N -75.77462768554688°E
# Elevation 65.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# h3t
# Performing coord search
# Coordinates 45.51845169067383°N -73.61068725585938°E
# Elevation 117.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# h9p
# Performing coord search
# Coordinates 45.44815444946289°N -73.77740478515625°E
# Elevation 28.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# n0r
# Performing coord search
# Coordinates 42.14411163330078°N -82.77371215820312°E
# Elevation 192.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# l9c
# Performing coord search
# Coordinates 23.0931453704834°N 69.57112884521484°E
# Elevation 150.0 m asl
# Timezone b'Asia/Kolkata' b'GMT+5:30'
# Timezone difference to GMT+0 19800 s
# p1n
# Performing coord search
# Coordinates -25.061511993408203°N -130.05386352539062°E
# Elevation 46.0 m asl
# Timezone b'Pacific/Pitcairn' b'GMT-8'
# Timezone difference to GMT+0 -28800 s
# t5x
# Performing coord search
# Coordinates 53.60280990600586°N -113.44827270507812°E
# Elevation 685.0 m asl
# Timezone b'America/Edmonton' b'GMT-7'
# Timezone difference to GMT+0 -25200 s
# p3p
# Performing coord search
# Coordinates 46.713531494140625°N -81.0°E
# Elevation 396.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# t6w
# Performing coord search
# Coordinates 53.39191436767578°N -113.65713500976562°E
# Elevation 691.0 m asl
# Timezone b'America/Edmonton' b'GMT-7'
# Timezone difference to GMT+0 -25200 s
# k0b
# Performing coord search
# Coordinates 45.51845169067383°N -74.740966796875°E
# Elevation 57.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# n7m
# Performing coord search
# Coordinates 42.4253044128418°N -82.20263671875°E
# Elevation 183.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# m4k
# Performing coord search
# Coordinates 43.6906852722168°N -79.4117431640625°E
# Elevation 121.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# p3n
# Performing coord search
# Coordinates 46.572933197021484°N -81.0289306640625°E
# Elevation 317.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# g7j
# Performing coord search
# Coordinates 48.400699615478516°N -71.1241455078125°E
# Elevation 132.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# l2t
# Performing coord search
# Coordinates 43.128292083740234°N -79.26974487304688°E
# Elevation 121.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# a0e
# Performing coord search
# Coordinates 47.5571174621582°N -54.6217041015625°E
# Elevation 302.0 m asl
# Timezone b'America/St_Johns' b'GMT-3:30'
# Timezone difference to GMT+0 -12600 s
# m6v
# Performing coord search
# Coordinates 3.690685272216797°N 73.19805145263672°E
# Elevation 0.0 m asl
# Timezone b'Indian/Maldives' b'GMT+5'
# Timezone difference to GMT+0 18000 s
# h3w
# Performing coord search
# Coordinates 45.51845169067383°N -73.61068725585938°E
# Elevation 74.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# j1k
# Performing coord search
# Coordinates 45.37785339355469°N -71.97183227539062°E
# Elevation 228.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# v0b
# Performing coord search
# Coordinates 49.666080474853516°N -115.69204711914062°E
# Elevation 1082.0 m asl
# Timezone b'America/Edmonton' b'GMT-7'
# Timezone difference to GMT+0 -25200 s
# e4s
# Performing coord search
# Coordinates 46.50263595581055°N -64.7191162109375°E
# Elevation 25.0 m asl
# Timezone b'America/Moncton' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# l9h
# Performing coord search
# Coordinates 43.268890380859375°N -79.91030883789062°E
# Elevation 92.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# t3r
# Performing coord search
# Coordinates 51.212650299072266°N -114.28056335449219°E
# Elevation 1218.0 m asl
# Timezone b'America/Edmonton' b'GMT-7'
# Timezone difference to GMT+0 -25200 s
# r1n
# Performing coord search
# Coordinates 49.94727325439453°N -98.31008911132812°E
# Elevation 264.0 m asl
# Timezone b'America/Winnipeg' b'GMT-6'
# Timezone difference to GMT+0 -21600 s
# h7x
# Performing coord search
# Coordinates 45.51845169067383°N -73.751953125°E
# Elevation 41.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# r4g
# Performing coord search
# Coordinates 36.94200134277344°N 14.703557968139648°E
# Elevation 557.0 m asl
# Timezone b'Europe/Rome' b'GMT+1'
# Timezone difference to GMT+0 3600 s
# m4n
# Performing coord search
# Coordinates 43.760982513427734°N -79.395751953125°E
# Elevation 162.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# m1v
# Performing coord search
# Coordinates 43.83127975463867°N -79.24359130859375°E
# Elevation 193.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# p3g
# Performing coord search
# Coordinates 46.432334899902344°N -80.9134521484375°E
# Elevation 238.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# t0a
# Performing coord search
# Coordinates 54.797889709472656°N -111.74256896972656°E
# Elevation 623.0 m asl
# Timezone b'America/Edmonton' b'GMT-7'
# Timezone difference to GMT+0 -25200 s
# e2a
# Performing coord search
# Coordinates 47.62741470336914°N -65.6837158203125°E
# Elevation 7.0 m asl
# Timezone b'America/Moncton' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# j6l
# Performing coord search
# Coordinates 26.326887130737305°N -99.89010620117188°E
# Elevation 292.0 m asl
# Timezone b'America/Monterrey' b'GMT-6'
# Timezone difference to GMT+0 -21600 s
# s7k
# Performing coord search
# Coordinates -0.1054481565952301°N -78.42556762695312°E
# Elevation 2516.0 m asl
# Timezone b'America/Guayaquil' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# m4w
# Performing coord search
# Coordinates 43.6906852722168°N -79.4117431640625°E
# Elevation 128.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# h9g
# Performing coord search
# Coordinates 45.44815444946289°N -73.77740478515625°E
# Elevation 42.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# v2n
# Performing coord search
# Coordinates 53.6731071472168°N -122.99424743652344°E
# Elevation 911.0 m asl
# Timezone b'America/Vancouver' b'GMT-8'
# Timezone difference to GMT+0 -28800 s
# k0s
# Performing coord search
# Coordinates 38.277679443359375°N -98.6351318359375°E
# Elevation 554.0 m asl
# Timezone b'America/Chicago' b'GMT-6'
# Timezone difference to GMT+0 -21600 s
# t4t
# Performing coord search
# Coordinates 52.337432861328125°N -115.0°E
# Elevation 984.0 m asl
# Timezone b'America/Edmonton' b'GMT-7'
# Timezone difference to GMT+0 -25200 s
# r3p
# Performing coord search
# Coordinates 49.876976013183594°N -97.20001220703125°E
# Elevation 233.0 m asl
# Timezone b'America/Winnipeg' b'GMT-6'
# Timezone difference to GMT+0 -21600 s
# e2n
# Performing coord search
# Coordinates 45.30755615234375°N -65.953125°E
# Elevation 96.0 m asl
# Timezone b'America/Moncton' b'GMT-4'
# Timezone difference to GMT+0 -14400 s
# k1x
# Performing coord search
# Coordinates 45.30755615234375°N -75.65625°E
# Elevation 111.0 m asl
# Timezone b'America/Toronto' b'GMT-5'
# Timezone difference to GMT+0 -18000 s
# t2v
# Performing coord search
# Coordinates 51.00175476074219°N -114.1502685546875°E
# Elevation 1087.0 m asl
# Timezone b'America/Edmonton' b'GMT-7'
# Timezone difference to GMT+0 -25200 s
# t5p
# Performing coord search
# Coordinates 53.53251266479492°N -113.57553100585938°E
# Elevation 675.0 m asl
# Timezone b'America/Edmonton' b'GMT-7'
# Timezone difference to GMT+0 -25200 s

# %% [markdown]
# # Calculate hourly heating requirement from annual heating and hourly weather data

# %%
heatpumpdata = ['HPCAP', 'HPEquipType', 'HPESTAR' ,'HPSOURCE', 'COP']
building_chars = ['HEATEDFLOORAREA', 'BUILDINGTYPE', 'HOUSEID', 'HOUSEREGION', 'YEARBUILT']
location_data = ['HOUSEREGION', 'CLIENTPCODE', 'CLIENTCITY']

thermal_envelope_metrics = ['EGHHLWALLS', 'EGHHLCEILING', 'EGHHLWINDOOR', 'EGHHLFOUND', 'EGHHLEXPOSEDFLR',  'EGHHLAIR']
energy_performance = ['EGHRATING', 'EGHSPACEENERGY', 'ERSENERGYINTENSITY']
energy_consumption_metrics = ['EGHFCONTOTAL' ,'EGHFCONELEC','EGHFCONNGAS','EGHFCONOIL' , 'EGHFCONPROP','EGHFCONWOOD','EGHFCONWOODGJ']
heating_specific_eng_consumption_metrics = ['EGHHEATFCONSE', 
                                            'EGHHEATFCONSG', 
                                            'EGHHEATFCONSO', 
                                            'EGHHEATFCONSP' ,
                                            'EGHHEATFCONSW',
                                            'ERSWATERHEATINGENERGY',
                                            'EGHSPACEENERGY',
                                            'ERSSPACECOOLENERGY']
weather_data = ['WEATHERLOC', 'WTHDATA', 'CoolingSeasonMonths', 'TMAIN', 'QTOT', 'QWARN']
temperature_setting = ['ThermostatCooling', 'ThermostatHeatingNighttime']
time_info = ['CREATIONDATE', 'ENTRYDATE']

#efficiency of the heating equipment

# %%
import pandas as pd 
# read a row from the ECCC
fname = '../data/raw_data/heatpump/ECCC_data_parts/ECCC_2023_part_10.xlsx'
housing_data = pd.read_excel(fname)
# Out:
#   Cell In[467], line 4
#     weather_base_folder = f'../data/raw_data/weather/by_FSA/{}_2023-01-01_2024-01-01.csv'
#                                                                                          ^
# SyntaxError: f-string: empty expression not allowed

# %%
weather_base_folder = '../data/raw_data/weather/by_FSA/{0}_2023-01-01_2024-01-01.csv'
base_indoor_temp = 20
housing_data_with_HP = housing_data[housing_data[' HPSOURCE'].isin(['Air', 'Water', 'Ground'])]
hp_data_row = housing_data_with_HP.iloc[52]

# read relevant data
building_fsa = hp_data_row[' CLIENTPCODE']
annual_heating_eng_req = hp_data_row[' EGHSPACEENERGY']
annual_cooling_eng_req = hp_data_row[' ERSSPACECOOLENERGY']
heatloss_data = np.array(hp_data_row[thermal_envelope_metrics])

weather_data = pd.read_csv(weather_base_folder.format(building_fsa))


# calculate the hourly temperature and wind factor 
temp_contribution = heatloss_data[0:-2].sum()
wind_contribution = heatloss_data[-1]

temp_fraction = temp_contribution/heatloss_data.sum()
wind_fraction = 1-temp_fraction

hourly_temp_data = np.array(weather_data['temperature_2m'])
hourly_wind_data = np.array(weather_data['wind_speed_10m'])
hourly_heating_degrees = base_indoor_temp - hourly_temp_data

hourly_heating_degrees[ hourly_heating_degrees <= 0] = 0
hourly_wind_data[hourly_heating_degrees <= 0] = 0

temp_factor = (annual_heating_eng_req*temp_fraction)/hourly_heating_degrees.sum()

wind_factor = (annual_heating_eng_req*wind_fraction)/np.sum(hourly_wind_data)

# calclulate the hourly heating energy 
hourly_heating_energy_temp = temp_factor*hourly_heating_degrees 
hourly_heating_energy_wind = wind_factor*hourly_wind_data

hourly_heating_energy_total = hourly_heating_energy_temp + hourly_heating_energy_wind
# add heating pattern into the mix

# %% [markdown]
# ## Plot hourly heat requirement vs temperature and wind

# %%
import matplotlib.pyplot as plt
start = 24*181
end = 24*182
plt.plot(np.array(weather_data['temperature_2m'])[start:end],label='Temp')
plt.plot(np.array(weather_data['wind_speed_10m'])[start: end], label='Wind')
plt.plot(hourly_heating_energy_temp[start: end], label='Heating temp')
plt.plot(hourly_heating_energy_wind[start: end], label='Heating wind')
plt.plot(hourly_heating_energy_total[start: end], label='Heating total')
plt.legend()

# %% [markdown]
# # Convert heat requirement to electricity consumption

# %% [markdown]
# ## Interpolate heatpump data

# %%
hp_data_file = '../data/raw_data/heatpump/heatpump_specifications.xlsx'
hp_data = pd.read_excel(hp_data_file)

# %%
plt.hist(housing_data_with_HP[' HPCAP']/3500, bins=[0,1,1.5,2,2.5,3,3.5,4,5])
# Out:
# (array([131., 135., 279., 505., 383., 356., 167., 296.]),
#  array([0. , 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 5. ]),
#  <BarContainer object of 8 artists>)

# %%
from scipy.interpolate import CubicSpline

interpolated_hp_data = pd.DataFrame(columns=['hp_cap_watts', 'temperature_c', 'cap_low','cap_high', 'cop_low', 'cop_high'])
cols_to_interpol = ['cap_low','cap_high', 'cop_low', 'cop_high']
hp_caps = [2.5, 3, 3.5]
for i in range(3):
    interp_df = pd.DataFrame(columns=['hp_cap_watts', 'temperature_c', 'cap_low','cap_high', 'cop_low', 'cop_high'])
    for col in cols_to_interpol:
        csl = CubicSpline(np.array(hp_data['temperature_c'][7*i:7*(i+1)]), np.array(hp_data[col][7*i:7*(i+1)]))
        strt_temp = -25
        end_temp = 20
        xnew = np.linspace(start_temp, end_temp, num=(end_temp-start_temp)*10+1)
        interp_data = csl(xnew)
        interp_df[col] = interp_data
    interp_df['temperature_c'] = xnew
    interp_df['hp_cap_watts'] = hp_caps[i]*3500
    interpolated_hp_data = pd.concat([interpolated_hp_data, interp_df])

#interpolated_hp_data.to_excel('../data/raw_data/heatpump/heatpump_specifications_interpolated.xlsx')
# Out:
# C:\Users\konar\AppData\Local\Temp\ipykernel_44412\3664096744.py:17: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   interpolated_hp_data = pd.concat([interpolated_hp_data, interp_df])

# %%
# 2d interpolation 
from scipy.interpolate import LinearNDInterpolator, RBFInterpolator, NearestNDInterpolator, RegularGridInterpolator
from scipy.interpolate import CubicSpline
import pandas as pd
hp_caps = [2.5, 3, 3.5]
hp_data_file = '../data/raw_data/heatpump/heatpump_specifications.xlsx'
hp_data = pd.read_excel(hp_data_file)

#spline fitting in 1d 
interpolated_hp_data = pd.DataFrame(columns=['hp_cap_watts', 'temperature_c', 'cap_low','cap_high', 'cop_low', 'cop_high'])
cols_to_interpol = ['cap_low','cap_high', 'cop_low', 'cop_high']
hp_caps = [2.5, 3, 3.5]
for i in range(3):
    interp_df = pd.DataFrame(columns=['hp_cap_watts', 'temperature_c', 'cap_low','cap_high', 'cop_low', 'cop_high'])
    for col in cols_to_interpol:
        csl = CubicSpline(np.array(hp_data['temperature_c'][7*i:7*(i+1)]), np.array(hp_data[col][7*i:7*(i+1)]))
        strt_temp = -25
        end_temp = 20
        xnew = np.linspace(start_temp, end_temp, num=(end_temp-start_temp)*10+1)
        interp_data = csl(xnew)
        interp_df[col] = interp_data
    interp_df['temperature_c'] = xnew
    interp_df['hp_cap_watts'] = hp_caps[i]*3500
    interpolated_hp_data = pd.concat([interpolated_hp_data, interp_df])

#interpolated_hp_data.to_excel('../data/raw_data/heatpump/heatpump_specifications_interpolated.xlsx')

#interpolation of the data 

hp_coeff_data_interpolated = {}
len_for_each_hp_data = xnew.shape[0]
for i in range(len(hp_caps)):
    
    x = np.array(interpolated_hp_data['temperature_c'][len_for_each_hp_data*i:len_for_each_hp_data*(i+1)])
    x = np.concatenate([x,x])
    y = np.concatenate([np.array(interpolated_hp_data['cap_low'][len_for_each_hp_data*i:len_for_each_hp_data*(i+1)]), 
                        np.array(interpolated_hp_data['cap_high'][len_for_each_hp_data*i:len_for_each_hp_data*(i+1)])])
    z = np.concatenate([np.array(interpolated_hp_data['cop_low'][len_for_each_hp_data*i:len_for_each_hp_data*(i+1)]), 
                        np.array(interpolated_hp_data['cop_high'][len_for_each_hp_data*i:len_for_each_hp_data*(i+1)])])
    interp = LinearNDInterpolator(list(zip(x,y)),z)
    strt_temp = -25
    end_temp = 20
    Xnew = np.linspace(start_temp, end_temp, num=(end_temp-start_temp)*10+1)
    Ynew = np.linspace(0, max(y), num=100)
    X,Y = np.meshgrid(Xnew,Ynew)
    Z = interp(X,Y)
    #add COP for cycling
    cycling_cop_penalty = (1 - 0.15) # from the ECCC heatpump report
    min_vals_for_temps = np.min(Z, where= ~np.isnan(Z), axis=0, initial=10)
    cycling_cop = min_vals_for_temps*cycling_cop_penalty
    for t in range(Z.shape[1]):
        cap_idx = int((y[t] - Ynew.min())/(Ynew.max()-Ynew.min())*len(Ynew))

        Z[0:cap_idx, t] = cycling_cop[t]
     
    hp_coeff_data_interpolated[hp_caps[i]] = {}
    hp_coeff_data_interpolated[hp_caps[i]]['COP_data'] = Z.tolist()
    hp_coeff_data_interpolated[hp_caps[i]]['temp_limits'] = [start_temp, end_temp]
    hp_coeff_data_interpolated[hp_caps[i]]['CAP_max'] = list(y[int(len(y)/2):])
    
with open('../data/formatted_data/heatpump/hp_coeff_data_interpolated.json', 'w') as fwrite:
    json.dump(hp_coeff_data_interpolated, fwrite)
# Out:
# C:\Users\konar\AppData\Local\Temp\ipykernel_8360\4204776735.py:24: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   interpolated_hp_data = pd.concat([interpolated_hp_data, interp_df])

# %%
#visualize the result
import numpy as np
Z = hp_coeff_data_interpolated['2.5']['COP_data']
start_temp = -25
end_temp = 20
Xnew = np.linspace(start_temp, end_temp, num=(end_temp-start_temp)*10+1)
Ynew = np.linspace(0, max(y), num=100)
X,Y = np.meshgrid(Xnew,Ynew)
plt.pcolormesh(X, Y, Z, shading='auto')
plt.colorbar()
plt.show()

# %% [markdown]
# ## Convert Heating requirement to electrical load

# %%
import json
import numpy as np
import matplotlib.pyplot as plt
with open('../data/formatted_data/heatpump/hp_coeff_data_interpolated.json', 'r') as fread:
    hp_coeff_data_interpolated = json.load(fread)

# %%
import math
def get_hp_electricity_usage(hp_size, cur_temp, cur_heat_req, hp_cop_data):
    '''
    Given the current heating load and size of the heat pump, 
    return the COP and the electricity used by the HP for the current load
    hp_cop_info: dictionary containing another dict:
        {hp_size}: {
        'temp_limits': tuple (min, max)
        'CAP_max': list of max capacity values for different temperatures 
        'COP_data': list(list) COP data for different temperature and capacity
                    outer_dim: capacity index
                    inner_dim: temperature index
                    }
    Returns the electric power required (float), the COP (float) and whether it needs backup heating system (bool)
    '''
    cur_hp_info = hp_cop_data[str(hp_size)]
    min_temp, max_temp = cur_hp_info['temp_limits']
    min_cap = 0
    max_cap = max(cur_hp_info['CAP_max'])
    max_cap_vals = cur_hp_info['CAP_max']
    temp_indx = int((cur_temp - min_temp)/(max_temp-min_temp)*len(cur_hp_info['COP_data'][0]))
    max_cap_temp = cur_hp_info['CAP_max'][temp_indx]
    cur_load_frac = cur_heat_req/(hp_size*3500)

    cur_cop = np.nan

    #due to the quirks of the interpolation some edge values are Nan
    #the loop below makes sure if a value is selected from the nan region
    #then it would select the closest non nan value for that given temperature
    
    while np.isnan(cur_cop):
        cur_load_frac = min(max_cap_temp, cur_load_frac)
        cap_indx = math.floor((cur_load_frac - min_cap)/(max_cap - min_cap)*len(cur_hp_info['COP_data']))
        max_cap_temp-=0.001
        cur_cop = cur_hp_info['COP_data'][cap_indx][temp_indx]
        
    return cur_heat_req/cur_cop, cur_cop, cur_heat_req/(hp_size*3500)>cur_hp_info['CAP_max'][temp_indx]

# %%
get_hp_electricity_usage(2.5, -10, 2.5*3500*1, hp_coeff_data_interpolated)
# Out:
# (4756.141770324616, 1.8397264889357567, True)

# %% [markdown]
# # Penetration rate of heat pumps

# %%
import pandas as pd
from matplotlib import pyplot as plt 
hp_penetration_rate_province = pd.read_csv('../../data/formatted_data/heatpump/hp_penetration_rate_province.csv')

# %%
from scipy.optimize import curve_fit
def logistic(t, L, k, t0):
    return L / (1 + np.exp(-k * (t - t0)))
    

forecast_penrate_provinces = pd.DataFrame(columns=['province', 'year', 'penetration_rate'])
penetration_forecast = {2024: 6, 2030: 13, 2040: 30, 2050: 50}
provinces = list(hp_penetration_rate_province['province'])
for province in provinces:
    years = []
    pen_rates = []
    forecast_penrate_one_province = pd.DataFrame(columns=['province', 'year', 'penetration_rate'])

    for year, p_rate in penetration_forecast.items():
        years.append(year)
        pen_rates.append(p_rate)
        
    cur_penrate_province = hp_penetration_rate_province[hp_penetration_rate_province['province']==province]['penetration_rate'].item()
    proportional_rate = cur_penrate_province/penetration_forecast[2024]
    pen_rates_proportional = np.array(pen_rates)*proportional_rate
    print(years, pen_rates_proportional)
    initial_guess = [pen_rates_proportional[-1], 0.1, 2030] 
    popt, _ = curve_fit(logistic, years, pen_rates_proportional, p0=initial_guess)
    pen_rates_forecast = logistic(years, *popt)
    #plt.plot(years, logistic(years, *popt), label=province)
    
plt.grid(True)
plt.legend()
# Out:
# [2024, 2030, 2040, 2050] [ 3.1         6.71666667 15.5        25.83333333]
# [2024, 2030, 2040, 2050] [ 4.6         9.96666667 23.         38.33333333]
# [2024, 2030, 2040, 2050] [ 4.5   9.75 22.5  37.5 ]
# [2024, 2030, 2040, 2050] [ 5.2        11.26666667 26.         43.33333333]
# [2024, 2030, 2040, 2050] [ 2.          4.33333333 10.         16.66666667]
# [2024, 2030, 2040, 2050] [ 6.4        13.86666667 32.         53.33333333]
# [2024, 2030, 2040, 2050] [ 7.9        17.11666667 39.5        65.83333333]
# [2024, 2030, 2040, 2050] [ 3.5         7.58333333 17.5        29.16666667]
# [2024, 2030, 2040, 2050] [ 8.6        18.63333333 43.         71.66666667]
# [2024, 2030, 2040, 2050] [ 3.5         7.58333333 17.5        29.16666667]
# [2024, 2030, 2040, 2050] [0.4        0.86666667 2.         3.33333333]

# %%
pen_rates, proportional_rate
# Out:
# ([6, 13, 30, 50],
#  0    0.516667
#  Name: penetration_rate, dtype: float64)

# %%
hp_penetration_rate_province
# Out:
#                      province  year  penetration_rate
# 0                     alberta  2024               3.1
# 1            british columbia  2024               4.6
# 2                    manitoba  2024               4.5
# 3               new brunswick  2024               5.2
# 4   newfoundland and labrador  2024               2.0
# 5                 nova scotia  2024               6.4
# 6                     ontario  2024               7.9
# 7        prince edward island  2024               3.5
# 8                      quebec  2024               8.6
# 9                saskatchewan  2024               3.5
# 10                territories  2024               0.4

# %%
import numpy as np
import pandas as pd

# Input Data
provinces = ["Province A", "Province B", "Province C"]
current_rates = [5, 10, 3]  # Current provincewide adoption rates (%)
nationwide_rate = 6  # Current nationwide adoption rate (%)
target_2030 = 13
target_2050 = 50

# Calculate Provincial Multipliers
multipliers = [rate / nationwide_rate for rate in current_rates]

# Define Growth Function (Linear Example)
def project_growth(current_rate, multiplier, target, years):
    annual_growth = (target - nationwide_rate) / years
    return [current_rate + annual_growth * multiplier * t for t in range(years + 1)]

# Generate Projections
years = list(range(2023, 2051))
projections = {province: project_growth(rate, mult, target_2050, 2050 - 2023)
               for province, rate, mult in zip(provinces, current_rates, multipliers)}

# Create DataFrame for Output
df = pd.DataFrame(projections, index=years)
print(df)
import seaborn as sns
sns.lineplot(df)
# Out:
#       Province A  Province B  Province C
# 2023    5.000000   10.000000    3.000000
# 2024    6.358025   12.716049    3.814815
# 2025    7.716049   15.432099    4.629630
# 2026    9.074074   18.148148    5.444444
# 2027   10.432099   20.864198    6.259259
# 2028   11.790123   23.580247    7.074074
# 2029   13.148148   26.296296    7.888889
# 2030   14.506173   29.012346    8.703704
# 2031   15.864198   31.728395    9.518519
# 2032   17.222222   34.444444   10.333333
# 2033   18.580247   37.160494   11.148148
# 2034   19.938272   39.876543   11.962963
# 2035   21.296296   42.592593   12.777778
# 2036   22.654321   45.308642   13.592593
# 2037   24.012346   48.024691   14.407407
# 2038   25.370370   50.740741   15.222222
# 2039   26.728395   53.456790   16.037037
# 2040   28.086420   56.172840   16.851852
# 2041   29.444444   58.888889   17.666667
# 2042   30.802469   61.604938   18.481481
# 2043   32.160494   64.320988   19.296296
# 2044   33.518519   67.037037   20.111111
# 2045   34.876543   69.753086   20.925926
# 2046   36.234568   72.469136   21.740741
# 2047   37.592593   75.185185   22.555556
# 2048   38.950617   77.901235   23.370370
# 2049   40.308642   80.617284   24.185185
# 2050   41.666667   83.333333   25.000000
# <Axes: >

# %% [markdown]
# # Expanding to nationwide

# %%
import pandas as pd 

df = pd.read_csv('../data/raw_data/heatpump/ECCC_2023.csv')
# Out:
# C:\Users\konar\AppData\Local\Temp\ipykernel_40872\737820427.py:3: DtypeWarning: Columns (47,52,87,88,89,151,157,158,183,213,223,227,230,233,256,257,259,275,279,284,326,330,331,347,351,353,358) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/raw_data/heatpump/ECCC_2023.csv')

# %%
relavant_info = ['HPSOURCE', 'HOUSEREGION']

hp_part_data = heat_pumpdata_eccc[relavant_info]
#hp_part_data['HOUSEREGION'][hp_part_data['HOUSEREGION']=='COLOMBIE-BRITANNIQUE'] = 'British Columbia'
hp_part_data.loc[hp_part_data['HOUSEREGION']=='COLOMBIE-BRITANNIQUE', 'HOUSEREGION'] = 'British Columbia'


hp_part_data['HOUSEREGION'] = hp_part_data['HOUSEREGION'].str.lower()


hp_part_data['Count'] = [1]*len(hp_part_data)
hp_part_data['has_HP'] = ['Yes']*len(hp_part_data)
hp_part_data['has_HP'][hp_part_data['HPSOURCE']=='N/A {no Heat Pump}'] = 'No'

hp_data_counts = hp_part_data.groupby(['HOUSEREGION', 'has_HP'], as_index=False).count()
entries_by_region = hp_part_data.groupby('HOUSEREGION', as_index=False).count()
regions = list(entries_by_region['HOUSEREGION'])
hp_percent = []
for region in regions:
    hp_percent.append(hp_data_counts[(hp_data_counts['HOUSEREGION']==region) & (hp_data_counts['has_HP']=='Yes')]['Count'].item()/entries_by_region.query('HOUSEREGION==@region')['Count'].item())

for r, p in zip(regions, hp_percent):
    print(r, p)
# Out:
# 506923

# %% [markdown]
# ## Convert heat requirement to energy

# %%
hourly_heating_energy_total
hourly_temp_data
interpolated_hp_data = pd.read_excel('../data/raw_data/heatpump/heatpump_specifications_interpolated.xlsx')
